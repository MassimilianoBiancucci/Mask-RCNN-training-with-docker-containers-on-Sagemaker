# %% [markdown]
# ## Sagemaker container lesion example
# In this example is launched a dummy container using spot instances, to test what's the behavior of the aws Sagemaker with docker containers, and what's the behaviour of the container whene it is terminated by aws due to lack of spot resources.</p>
# <p>In this example is simulated by a dummy python script (into the container) that performs similar actions that a normal training script with tensorflow or other framework should do, more specificaly:
#
# - Fake checkpoints are written in txt format in the folder `/opt/ml/checkpoints/`.
#
# - Fake tensorboard records are written every 20 seconds into the folder `/opt/ml/output/tensorboard/`, for check the real-time prensence into the s3 bucket folder  specified.
#
# - Furthermore the tree command is executed in the path `/opt/ml/` for inspect the folder structure created by sagemaker, and the result is stored in the `/opt/output/data/` folder as a txt file.

# %%
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.debugger import TensorBoardOutputConfig

# %% [markdown]
# In this section is recovered the Sagemaker bucket generated by default from the service

# %%
# default sagemaker bucket name request 
sagemaker_session = sagemaker.session.Session()
sagemaker_default_bucket = sagemaker_session.default_bucket()

print("bucket generated by sagemacker:" + sagemaker_default_bucket)
# Out:
# bucket generated by sagemacker:sagemaker-eu-west-1-011827850615

# %%
############################  JOB NAME  ####################################

# job-name definition:
# every multi-job session of training jobs is characterized by a base-job-name
# the job-name on the contrary is the identifier of the single training job.
# The job-name must be different for each training job and should be used to
# divide the results of different training jobs into specific folders.
job_name = 'test-28'

# %% [markdown]
# ## Defining the s3 bucket for the training job
# In this section are defined all the nedeed variables that specify the paths to s3 buckets for the inputs and outputs data.
#
# It's worth spending a few words about the configuration of the TensorBoardOutputConfig, this path can be used for tensorboard data if you use tensorflow or for other types of files that is important for you to take out of the container during the training process. in this example we write some txt files filled with random chearacters in the `container_local_output_path` and this files became available in the `s3_output_path` relative to the TensorBoardOutputConfig in a few seconds.

# %%
############################   INPUTS  ####################################

# repositroy ECR containing the docker image configured to be executed by Sagemaker
# ecr_container_uri = "<your aws id>.dkr.ecr.<your aws region>.amazonaws.com/<your repo name:your repo tag>"
ecr_container_uri = "011827850615.dkr.ecr.eu-west-1.amazonaws.com/maskrcnn_repo_test:lesion"
#ecr_container_uri = "011827850615.dkr.ecr.eu-west-1.amazonaws.com/maskrcnn_repo_test:lesion_2"

# s3 path containing the dataset needed for training the model
dataset_bucket = "s3://datsetsbucket/isic2018/"

# s3 path containing the model with pretrained weights, in the next example in this folder would be
# stored the Mask R-CNN model trained on COCO. 
model_bucket = 's3://cermodelbucket'

############################  OUTPUTS  ####################################

# s3 path where are stored the results of the instance profiler and any other data saved during the training in the folder /opt/ml/output/data/
output_path = f's3://{sagemaker_default_bucket}/output'

# s3 path where are stored the checkpoints of the training proces
checkpoints_path = f'{output_path}/{job_name}/checkpoints'

# internal paths for checkpoints and tenorboard logs passed to the container as env variables
user_defined_env_vars = {"checkpoints": "/opt/ml/checkpoints",
                        "tensorboard": "/opt/ml/output/tensorboard"}

# Definition of s3 target bucket folder for the tensorboard outputs and container folder where the tensorboard record must to be placed.
# it's possible to place the tensorboard output in other places but sagemaker copy that records into '/opt/ml/output/tensorboard' so we decide to
# put the records directly in there.
# Note: in the path 's3://testtflogs/logs' the recors are divided into folders related to the job-name in this example the output of tensorboard
# should be fine in 's3://testtflogs/logs/test-11'
tensorboard_output_config = TensorBoardOutputConfig(
    s3_output_path='s3://testtflogs/logs',
    container_local_output_path=user_defined_env_vars['tensorboard']
)

# %% [markdown]
# In this section are recovered the execution role ARN associated to this notebook, that will be passed to the estimator for launching the training job, be sure to give permissions to use other buckets to this role, otherwise it will only be possible to use buckets starting with the sagemaker keyword, in this case the permission is needed.

# %%
# if you are running the code from jupiter
# getting the execution role of this instance of sagemaker notebook
# role = get_execution_role()
# print(role)

# if you are running the code from local
role = 'arn:aws:iam::011827850615:role/service-role/AmazonSageMaker-ExecutionRole-20210522T125188'
# role = 'arn:aws:iam::<your aws id>:role/service-role/<your role name>'

# %% [markdown]
# Definitions of regex for logs extraction from stdout of the training script in the container

# %%
metrics = [
    {"Name": "loss",                    "Regex": r"\sloss:\s(\d+.?\d*)\s-"},
    {"Name": "rpn_class_loss",          "Regex": r"\srpn_class_loss:\s(\d+.?\d*)\s-"},
    {"Name": "rpn_bbox_loss",           "Regex": r"\srpn_bbox_loss:\s(\d+.?\d*)\s-"},
    {"Name": "mrcnn_class_loss",        "Regex": r"\smrcnn_class_loss:\s(\d+.?\d*)\s-"},
    {"Name": "mrcnn_mask_loss",         "Regex": r"\smrcnn_mask_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_loss",                "Regex": r"\smrcnn_bbox_loss:\s(\d+.?\d*)\s-"},
    {"Name": "mrcnn_bbox_loss",         "Regex": r"\sval_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_rpn_class_loss",      "Regex": r"\sval_rpn_class_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_rpn_bbox_loss",       "Regex": r"\sval_rpn_bbox_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_mrcnn_class_loss",    "Regex": r"\sval_mrcnn_class_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_mrcnn_bbox_loss",     "Regex": r"\sval_mrcnn_bbox_loss:\s(\d+.?\d*)\s-"},
    {"Name": "val_mrcnn_mask_loss",     "Regex": r"\sval_mrcnn_mask_loss:\s(\d+.?\d*)"},
    {"Name": "ms/step",                 "Regex": r"\s(\d+)ms\/step"}
]

# %% [markdown]
# In this section are defined the hyperparameters, this values are passed to the estimator definitions and would be reachable from the trainning script in the container as commandline arguments, or like environment variables whit this notation `SM_HP_{hyperparameter_name}`, es. `SM_HP_HP1` or `SM_HP_BATCH` in this case

# %%
# hyperparameters definition
hyperparameters = {
    "NAME": "lesion", 
    "GPU_COUNT": 4, 
    "IMAGES_PER_GPU": 2,
    "CLASS_NAMES": "{\"1\": \"lesion\"}",
    "TRAINING_SPLIT": 0.8,
    "TRAIN_SEQ": "[\
        {\"epochs\": 20, \"layers\": \"heads\", \"lr\": 0.001},\
        {\"epochs\": 40, \"layers\": \"all\", \"lr\": 0.0001 }\
    ]"
}

# %% [markdown]
# ## Setup the training job
# This is the key function of the script, in there are configured al the training job parameters, are passed all the path that was defined earlier, the hyperparameters and are defined many settings relative to the type of machine used for the job, and in witch mode should run.
#
# More specificaly we chose to run in spot mode (`use_spot_instances = True`), in this mode the cost of the training goes down from 50% to 80% depending on the instance type chosen and by the availability of the machine, this mode enable aws to sell at lower price unused compute capability in the cloud and can stop your application if someone need this machine in on-demand mode (without any discount).
#
# Whene you chose to run in spot mode two more variables should be set, `max_run` and `max_wait`, this variables specify how match time in seconds the container could run and the second specify in the case that it will be stoped by aws how much time the program should wait that spot instances became available again for restart your container, if one of the two limits are exceeded the training job will be terminated.
#
# For other info about the parameters of this function you can check the [reference](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html)

# %%
training_test = sagemaker.estimator.Estimator(
    # container image 
    image_uri    = ecr_container_uri, 
    # role of sagemaker notebook instance
    role         = role, 
    # number of instance to launch
    instance_count = 1, 
    # if you want to use local mode
    #train_instance_type="local",  
    # type of instance in which place the training job
    #instance_type = 'ml.g4dn.2xlarge',
    instance_type = 'ml.g4dn.12xlarge',
    #instance_type = 'ml.p3.2xlarge',
    # space in GB of the storage attached to the ec2 instance
    volume_size  = 50,
    # max number of seconds of running for the job until the termination of the process
    max_run      = 10*3600,
    # s3 path where will be placed the results of the profiler and the content of /opt/ml/output/data/ path as tar.gz file 
    output_path  = output_path, 
    # prefix for the trainng job name, if not specified generated automatically
    #base_job_name="training-test", 
    # training job hyperparameters, parameters passed as command line arguments
    hyperparameters = hyperparameters, 
    # list of tags for the job
    tags = [{"Key": "CER", "Value": "1"},],
    # s3 path where to find the data needed for the start of the training job like the pretrained model,and that will be copied into the folder /opt/ml/inputs/data/model (sovrascrivibile da model_channel_name)
    model_uri    = model_bucket, 
    # name of the chanel where will be saved the data included in the path model_uri (/opt/ml/inputs/data/<model_channel_name>)
    model_channel_name = 'model', 
    # dict regexs for metrics extraction from stdout {"<metric name>":"<regex for logs estraction>", ...}
    metric_definitions = metrics, 
    # flag for enabling the spot training
    use_spot_instances = True, 
    # max time of waiting for spot instance to became available again
    max_wait = 24*3600, 
    # s3 chekpoints target path
    checkpoint_s3_uri = checkpoints_path, 
    # default: '/opt/ml/checkpoints'
    checkpoint_local_path = user_defined_env_vars['checkpoints'], 
    # SageMaker Debugger rules
    #rules = ; 
    # Tensorboard output configuration
    tensorboard_output_config = tensorboard_output_config,
    # dict usefull for setting more environment variables into the container
    environment = user_defined_env_vars,
    # max number of try to restart the job if it's finish unespectedly
    #max_retry_attempts =   
)

# %% [markdown]
# ## Launching the training job
# In this section of the notebook the training-job start, using the `.fit()` method of estimator object.
#
# This method have the input parameter that could be defined as a dict with a key and a path to local storage or s3 bucket where are present files that we would download to the container, note that the number of path that could be specified are not limited and for each input path in the container into `/opt/ml/inputs/` is created one folder with the name equal to the passed key name and containing the data into the argument path. In this case we only passed one path to input param and we have as a result `/opt/ml/inputs/dataset/` into the container filled with the same data placed into `dataset_bucket ='s3://datsetsbucket/isic2018/test_dataset/'`, if you pass this dict with more values the result will be an `inputs/` folder populated with more subfolders and relative data.
#
# The `job_name` is a very important parameter this enable you to distinguish from different jobs launched simultaniously or in different moments and permit to distinguish the training job in the training job panel for this reason they can't have the same name, if you launch two training job with the same name the result is an error and the container dosen't start.
#
# Another note is relative to wait and logs parameters, this parameters enable you to watch the logs relative to the startup of the machine and to watch the training job machine logs outputs at the end of the training process (it's not possible to see the training job stdout in real-time). With this configuration the function fit don't terminate until the job isn't finished, but if you don't enable the wait parameter the job start and fit function terminate so you can launch other functions or other jobs,  so to see the logs the wait param should be true.
#
# If something is unclear you can check the relative [reference](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html)

# %%
training_test.fit(
    inputs      = {
        'dataset': dataset_bucket
    },
    job_name    = job_name,
    wait        = True,
    logs        = 'All'
)
# Out:
# 2021-05-30 17:24:09 Starting - Starting the training job...
# 2021-05-30 17:24:32 Starting - Launching requested ML instancesProfilerReport-1622395448: InProgress
# ......
# 2021-05-30 17:25:32 Starting - Preparing the instances for training.........
# 2021-05-30 17:27:12 Downloading - Downloading input data......
# 2021-05-30 17:28:12 Training - Downloading the training image.........
# 2021-05-30 17:29:53 Training - Training image download completed. Training in progress.2021-05-30 17:29:37,575 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-30 17:29:43,859 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-30 17:29:43,897 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-30 17:29:43,906 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "model": "/opt/ml/input/data/model",
#         "dataset": "/opt/ml/input/data/dataset"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "GPU_COUNT": 4,
#         "CLASS_NAMES": {
#             "1": "lesion"
#         },
#         "IMAGES_PER_GPU": 2,
#         "TRAINING_SPLIT": 0.8,
#         "TRAIN_SEQ": [
#             {
#                 "epochs": 20,
#                 "layers": "heads",
#                 "lr": 0.001
#             },
#             {
#                 "epochs": 40,
#                 "layers": "all",
#                 "lr": 0.0001
#             }
#         ],
#         "NAME": "lesion"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "model": {
#             "ContentType": "application/x-sagemaker-model",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "dataset": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "test-28",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "lesions_sagemaker",
#     "network_interface_name": "eth0",
#     "num_cpus": 48,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "lesions_sagemaker.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"CLASS_NAMES":{"1":"lesion"},"GPU_COUNT":4,"IMAGES_PER_GPU":2,"NAME":"lesion","TRAINING_SPLIT":0.8,"TRAIN_SEQ":[{"epochs":20,"layers":"heads","lr":0.001},{"epochs":40,"layers":"all","lr":0.0001}]}
# SM_USER_ENTRY_POINT=lesions_sagemaker.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"dataset":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["dataset","model"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=lesions_sagemaker
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=48
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"dataset":"/opt/ml/input/data/dataset","model":"/opt/ml/input/data/model"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"CLASS_NAMES":{"1":"lesion"},"GPU_COUNT":4,"IMAGES_PER_GPU":2,"NAME":"lesion","TRAINING_SPLIT":0.8,"TRAIN_SEQ":[{"epochs":20,"layers":"heads","lr":0.001},{"epochs":40,"layers":"all","lr":0.0001}]},"input_config_dir":"/opt/ml/input/config","input_data_config":{"dataset":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"test-28","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"lesions_sagemaker","network_interface_name":"eth0","num_cpus":48,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"lesions_sagemaker.py"}
# SM_USER_ARGS=["--CLASS_NAMES","1=lesion","--GPU_COUNT","4","--IMAGES_PER_GPU","2","--NAME","lesion","--TRAINING_SPLIT","0.8","--TRAIN_SEQ","[{'epochs': 20, 'layers': 'heads', 'lr': 0.001}, {'epochs': 40, 'layers': 'all', 'lr': 0.0001}]"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_MODEL=/opt/ml/input/data/model
# SM_CHANNEL_DATASET=/opt/ml/input/data/dataset
# SM_HP_GPU_COUNT=4
# SM_HP_CLASS_NAMES={"1":"lesion"}
# SM_HP_IMAGES_PER_GPU=2
# SM_HP_TRAINING_SPLIT=0.8
# SM_HP_TRAIN_SEQ=[{"epochs":20,"layers":"heads","lr":0.001},{"epochs":40,"layers":"all","lr":0.0001}]
# SM_HP_NAME=lesion
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 lesions_sagemaker.py --CLASS_NAMES 1=lesion --GPU_COUNT 4 --IMAGES_PER_GPU 2 --NAME lesion --TRAINING_SPLIT 0.8 --TRAIN_SEQ [{'epochs': 20, 'layers': 'heads', 'lr': 0.001}, {'epochs': 40, 'layers': 'all', 'lr': 0.0001}]
#
#
# training samples:2075
# validations samples:519
#
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# CLASS_NAMES                    {'1': 'lesion'}
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      4
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           lesion
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                259
# TOP_DOWN_PYRAMID_SIZE          256
# TRAINING_SPLIT                 0.8
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# TRAIN_SEQ                      [{'epochs': 20, 'layers': 'heads', 'lr': 0.001}, {'epochs': 40, 'layers': 'all', 'lr': 0.0001}]
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               64
# WEIGHT_DECAY                   0.0001
#
#
# checkpoints folder empty...
# [{'epochs': 20, 'layers': 'heads', 'lr': 0.001}, {'epochs': 40, 'layers': 'all', 'lr': 0.0001}]
# <class 'list'>
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /opt/ml/checkpoints/lesion/mask_rcnn_lesion_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/20
#   1/259 [..............................] - ETA: 5:01:59 - loss: 5.7377 - rpn_class_loss: 0.0117 - rpn_bbox_loss: 1.7484 - mrcnn_class_loss: 0.7002 - mrcnn_bbox_loss: 0.8900 - mrcnn_mask_loss: 2.3874
#   2/259 [..............................] - ETA: 2:32:55 - loss: 5.4542 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 1.7391 - mrcnn_class_loss: 0.5097 - mrcnn_bbox_loss: 0.8820 - mrcnn_mask_loss: 2.3118
#   3/259 [..............................] - ETA: 1:43:09 - loss: 5.1552 - rpn_class_loss: 0.0115 - rpn_bbox_loss: 1.7215 - mrcnn_class_loss: 0.3730 - mrcnn_bbox_loss: 0.8630 - mrcnn_mask_loss: 2.1861
#   4/259 [..............................] - ETA: 1:18:17 - loss: 4.8446 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 1.6941 - mrcnn_class_loss: 0.2938 - mrcnn_bbox_loss: 0.8261 - mrcnn_mask_loss: 2.0193
#   5/259 [..............................] - ETA: 1:03:21 - loss: 4.5622 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 1.6560 - mrcnn_class_loss: 0.2473 - mrcnn_bbox_loss: 0.8052 - mrcnn_mask_loss: 1.8425
#   6/259 [..............................] - ETA: 53:23 - loss: 4.2878 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 1.6091 - mrcnn_class_loss: 0.2170 - mrcnn_bbox_loss: 0.7786 - mrcnn_mask_loss: 1.6721
#   7/259 [..............................] - ETA: 46:16 - loss: 4.0426 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 1.5542 - mrcnn_class_loss: 0.1949 - mrcnn_bbox_loss: 0.7534 - mrcnn_mask_loss: 1.5293
#   8/259 [..............................] - ETA: 40:56 - loss: 3.8190 - rpn_class_loss: 0.0105 - rpn_bbox_loss: 1.4911 - mrcnn_class_loss: 0.1773 - mrcnn_bbox_loss: 0.7208 - mrcnn_mask_loss: 1.4193
#   9/259 [>.............................] - ETA: 36:46 - loss: 3.6237 - rpn_class_loss: 0.0103 - rpn_bbox_loss: 1.4204 - mrcnn_class_loss: 0.1631 - mrcnn_bbox_loss: 0.6933 - mrcnn_mask_loss: 1.3366
#  10/259 [>.............................] - ETA: 33:26 - loss: 3.4493 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 1.3435 - mrcnn_class_loss: 0.1511 - mrcnn_bbox_loss: 0.6725 - mrcnn_mask_loss: 1.2724
#  11/259 [>.............................] - ETA: 30:44 - loss: 3.2901 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 1.2632 - mrcnn_class_loss: 0.1418 - mrcnn_bbox_loss: 0.6528 - mrcnn_mask_loss: 1.2226
#  12/259 [>.............................] - ETA: 28:27 - loss: 3.1443 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 1.1824 - mrcnn_class_loss: 0.1341 - mrcnn_bbox_loss: 0.6383 - mrcnn_mask_loss: 1.1802
#  13/259 [>.............................] - ETA: 26:31 - loss: 3.0164 - rpn_class_loss: 0.0090 - rpn_bbox_loss: 1.1138 - mrcnn_class_loss: 0.1274 - mrcnn_bbox_loss: 0.6230 - mrcnn_mask_loss: 1.1432
#  14/259 [>.............................] - ETA: 24:52 - loss: 2.9043 - rpn_class_loss: 0.0088 - rpn_bbox_loss: 1.0579 - mrcnn_class_loss: 0.1216 - mrcnn_bbox_loss: 0.6051 - mrcnn_mask_loss: 1.1109
#  15/259 [>.............................] - ETA: 23:25 - loss: 2.8037 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 1.0094 - mrcnn_class_loss: 0.1169 - mrcnn_bbox_loss: 0.5865 - mrcnn_mask_loss: 1.0824
#  16/259 [>.............................] - ETA: 22:09 - loss: 2.7105 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.9657 - mrcnn_class_loss: 0.1123 - mrcnn_bbox_loss: 0.5676 - mrcnn_mask_loss: 1.0566
#  17/259 [>.............................] - ETA: 21:02 - loss: 2.6241 - rpn_class_loss: 0.0081 - rpn_bbox_loss: 0.9254 - mrcnn_class_loss: 0.1082 - mrcnn_bbox_loss: 0.5498 - mrcnn_mask_loss: 1.0326
#  18/259 [=>............................] - ETA: 20:03 - loss: 2.5436 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.8874 - mrcnn_class_loss: 0.1052 - mrcnn_bbox_loss: 0.5327 - mrcnn_mask_loss: 1.0105
#  19/259 [=>............................] - ETA: 19:10 - loss: 2.4685 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.8507 - mrcnn_class_loss: 0.1019 - mrcnn_bbox_loss: 0.5178 - mrcnn_mask_loss: 0.9904
#  20/259 [=>............................] - ETA: 18:22 - loss: 2.3982 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.8149 - mrcnn_class_loss: 0.0997 - mrcnn_bbox_loss: 0.5042 - mrcnn_mask_loss: 0.9718
#  21/259 [=>............................] - ETA: 17:38 - loss: 2.3306 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.7817 - mrcnn_class_loss: 0.0972 - mrcnn_bbox_loss: 0.4900 - mrcnn_mask_loss: 0.9544
#  22/259 [=>............................] - ETA: 16:58 - loss: 2.2674 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.7517 - mrcnn_class_loss: 0.0946 - mrcnn_bbox_loss: 0.4757 - mrcnn_mask_loss: 0.9382
#  23/259 [=>............................] - ETA: 16:21 - loss: 2.2090 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.7244 - mrcnn_class_loss: 0.0924 - mrcnn_bbox_loss: 0.4620 - mrcnn_mask_loss: 0.9230
#  24/259 [=>............................] - ETA: 15:48 - loss: 2.1533 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.6992 - mrcnn_class_loss: 0.0900 - mrcnn_bbox_loss: 0.4481 - mrcnn_mask_loss: 0.9088
#  25/259 [=>............................] - ETA: 15:17 - loss: 2.0994 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.6752 - mrcnn_class_loss: 0.0877 - mrcnn_bbox_loss: 0.4347 - mrcnn_mask_loss: 0.8949
#  26/259 [==>...........................] - ETA: 14:48 - loss: 2.0483 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.6522 - mrcnn_class_loss: 0.0855 - mrcnn_bbox_loss: 0.4221 - mrcnn_mask_loss: 0.8816
#  27/259 [==>...........................] - ETA: 14:22 - loss: 2.0008 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.6301 - mrcnn_class_loss: 0.0837 - mrcnn_bbox_loss: 0.4113 - mrcnn_mask_loss: 0.8689
#  28/259 [==>...........................] - ETA: 13:57 - loss: 1.9556 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.6094 - mrcnn_class_loss: 0.0819 - mrcnn_bbox_loss: 0.4009 - mrcnn_mask_loss: 0.8566
#  29/259 [==>...........................] - ETA: 13:34 - loss: 1.9124 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.5901 - mrcnn_class_loss: 0.0800 - mrcnn_bbox_loss: 0.3906 - mrcnn_mask_loss: 0.8450
#  30/259 [==>...........................] - ETA: 13:12 - loss: 1.8717 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.5721 - mrcnn_class_loss: 0.0783 - mrcnn_bbox_loss: 0.3807 - mrcnn_mask_loss: 0.8340
#  31/259 [==>...........................] - ETA: 12:51 - loss: 1.8320 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.5549 - mrcnn_class_loss: 0.0766 - mrcnn_bbox_loss: 0.3709 - mrcnn_mask_loss: 0.8230
#  32/259 [==>...........................] - ETA: 12:32 - loss: 1.7940 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.5385 - mrcnn_class_loss: 0.0751 - mrcnn_bbox_loss: 0.3617 - mrcnn_mask_loss: 0.8122
#  33/259 [==>...........................] - ETA: 12:14 - loss: 1.7575 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.5229 - mrcnn_class_loss: 0.0735 - mrcnn_bbox_loss: 0.3529 - mrcnn_mask_loss: 0.8018
#  34/259 [==>...........................] - ETA: 11:57 - loss: 1.7228 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.5082 - mrcnn_class_loss: 0.0721 - mrcnn_bbox_loss: 0.3446 - mrcnn_mask_loss: 0.7915
#  35/259 [===>..........................] - ETA: 11:40 - loss: 1.6894 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.4944 - mrcnn_class_loss: 0.0709 - mrcnn_bbox_loss: 0.3366 - mrcnn_mask_loss: 0.7813
#  36/259 [===>..........................] - ETA: 11:26 - loss: 1.6573 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.4812 - mrcnn_class_loss: 0.0697 - mrcnn_bbox_loss: 0.3288 - mrcnn_mask_loss: 0.7713
#  37/259 [===>..........................] - ETA: 11:11 - loss: 1.6267 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.4687 - mrcnn_class_loss: 0.0686 - mrcnn_bbox_loss: 0.3214 - mrcnn_mask_loss: 0.7619
#  38/259 [===>..........................] - ETA: 10:57 - loss: 1.5972 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.4567 - mrcnn_class_loss: 0.0675 - mrcnn_bbox_loss: 0.3144 - mrcnn_mask_loss: 0.7526
#  39/259 [===>..........................] - ETA: 10:44 - loss: 1.5685 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.4453 - mrcnn_class_loss: 0.0662 - mrcnn_bbox_loss: 0.3075 - mrcnn_mask_loss: 0.7436
#  40/259 [===>..........................] - ETA: 10:31 - loss: 1.5409 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.4344 - mrcnn_class_loss: 0.0651 - mrcnn_bbox_loss: 0.3008 - mrcnn_mask_loss: 0.7346
#  41/259 [===>..........................] - ETA: 10:19 - loss: 1.5144 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.4241 - mrcnn_class_loss: 0.0642 - mrcnn_bbox_loss: 0.2944 - mrcnn_mask_loss: 0.7258
#  42/259 [===>..........................] - ETA: 10:08 - loss: 1.4892 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.4142 - mrcnn_class_loss: 0.0633 - mrcnn_bbox_loss: 0.2884 - mrcnn_mask_loss: 0.7174
#  43/259 [===>..........................] - ETA: 9:57 - loss: 1.4649 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4046 - mrcnn_class_loss: 0.0624 - mrcnn_bbox_loss: 0.2826 - mrcnn_mask_loss: 0.7094
#  44/259 [====>.........................] - ETA: 9:46 - loss: 1.4417 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.3955 - mrcnn_class_loss: 0.0614 - mrcnn_bbox_loss: 0.2773 - mrcnn_mask_loss: 0.7016
#  45/259 [====>.........................] - ETA: 9:36 - loss: 1.4192 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.3868 - mrcnn_class_loss: 0.0608 - mrcnn_bbox_loss: 0.2720 - mrcnn_mask_loss: 0.6939
#  46/259 [====>.........................] - ETA: 9:26 - loss: 1.3974 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.3785 - mrcnn_class_loss: 0.0600 - mrcnn_bbox_loss: 0.2669 - mrcnn_mask_loss: 0.6863
#  47/259 [====>.........................] - ETA: 9:17 - loss: 1.3761 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3706 - mrcnn_class_loss: 0.0590 - mrcnn_bbox_loss: 0.2620 - mrcnn_mask_loss: 0.6789
#  48/259 [====>.........................] - ETA: 9:07 - loss: 1.3558 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3629 - mrcnn_class_loss: 0.0583 - mrcnn_bbox_loss: 0.2573 - mrcnn_mask_loss: 0.6717
#  49/259 [====>.........................] - ETA: 8:59 - loss: 1.3788 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3842 - mrcnn_class_loss: 0.0581 - mrcnn_bbox_loss: 0.2645 - mrcnn_mask_loss: 0.6663
#  50/259 [====>.........................] - ETA: 8:50 - loss: 1.3972 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.4028 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.2701 - mrcnn_mask_loss: 0.6607
#  51/259 [====>.........................] - ETA: 8:42 - loss: 1.4090 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4174 - mrcnn_class_loss: 0.0577 - mrcnn_bbox_loss: 0.2732 - mrcnn_mask_loss: 0.6549
#  52/259 [=====>........................] - ETA: 8:34 - loss: 1.4162 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4276 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.2752 - mrcnn_mask_loss: 0.6497
#  53/259 [=====>........................] - ETA: 8:26 - loss: 1.4169 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4328 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.2761 - mrcnn_mask_loss: 0.6441
#  54/259 [=====>........................] - ETA: 8:19 - loss: 1.4161 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.4338 - mrcnn_class_loss: 0.0586 - mrcnn_bbox_loss: 0.2782 - mrcnn_mask_loss: 0.6396
#  55/259 [=====>........................] - ETA: 8:12 - loss: 1.4143 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.4324 - mrcnn_class_loss: 0.0598 - mrcnn_bbox_loss: 0.2807 - mrcnn_mask_loss: 0.6356
#  56/259 [=====>........................] - ETA: 8:05 - loss: 1.4111 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4312 - mrcnn_class_loss: 0.0608 - mrcnn_bbox_loss: 0.2822 - mrcnn_mask_loss: 0.6310
#  57/259 [=====>........................] - ETA: 7:58 - loss: 1.4065 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4301 - mrcnn_class_loss: 0.0615 - mrcnn_bbox_loss: 0.2821 - mrcnn_mask_loss: 0.6270
#  58/259 [=====>........................] - ETA: 7:51 - loss: 1.4005 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4287 - mrcnn_class_loss: 0.0619 - mrcnn_bbox_loss: 0.2815 - mrcnn_mask_loss: 0.6226
#  59/259 [=====>........................] - ETA: 7:45 - loss: 1.3940 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4268 - mrcnn_class_loss: 0.0622 - mrcnn_bbox_loss: 0.2810 - mrcnn_mask_loss: 0.6182
#  60/259 [=====>........................] - ETA: 7:39 - loss: 1.3866 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4245 - mrcnn_class_loss: 0.0622 - mrcnn_bbox_loss: 0.2801 - mrcnn_mask_loss: 0.6138
#  61/259 [======>.......................] - ETA: 7:33 - loss: 1.3781 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4218 - mrcnn_class_loss: 0.0623 - mrcnn_bbox_loss: 0.2787 - mrcnn_mask_loss: 0.6095
#  62/259 [======>.......................] - ETA: 7:27 - loss: 1.3681 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.4186 - mrcnn_class_loss: 0.0620 - mrcnn_bbox_loss: 0.2769 - mrcnn_mask_loss: 0.6048
#  63/259 [======>.......................] - ETA: 7:21 - loss: 1.3578 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.4148 - mrcnn_class_loss: 0.0616 - mrcnn_bbox_loss: 0.2753 - mrcnn_mask_loss: 0.6003
#  64/259 [======>.......................] - ETA: 7:15 - loss: 1.3470 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.4107 - mrcnn_class_loss: 0.0614 - mrcnn_bbox_loss: 0.2734 - mrcnn_mask_loss: 0.5960
#  65/259 [======>.......................] - ETA: 7:10 - loss: 1.3363 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.4064 - mrcnn_class_loss: 0.0610 - mrcnn_bbox_loss: 0.2714 - mrcnn_mask_loss: 0.5918
#  66/259 [======>.......................] - ETA: 7:04 - loss: 1.3257 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.4023 - mrcnn_class_loss: 0.0606 - mrcnn_bbox_loss: 0.2695 - mrcnn_mask_loss: 0.5875
#  67/259 [======>.......................] - ETA: 6:59 - loss: 1.3150 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.3984 - mrcnn_class_loss: 0.0602 - mrcnn_bbox_loss: 0.2674 - mrcnn_mask_loss: 0.5833
#  68/259 [======>.......................] - ETA: 6:54 - loss: 1.3042 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.3945 - mrcnn_class_loss: 0.0599 - mrcnn_bbox_loss: 0.2650 - mrcnn_mask_loss: 0.5791
#  69/259 [======>.......................] - ETA: 6:49 - loss: 1.2934 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3904 - mrcnn_class_loss: 0.0595 - mrcnn_bbox_loss: 0.2629 - mrcnn_mask_loss: 0.5750
#  70/259 [=======>......................] - ETA: 6:44 - loss: 1.2829 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3863 - mrcnn_class_loss: 0.0592 - mrcnn_bbox_loss: 0.2608 - mrcnn_mask_loss: 0.5708
#  71/259 [=======>......................] - ETA: 6:39 - loss: 1.2718 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3823 - mrcnn_class_loss: 0.0588 - mrcnn_bbox_loss: 0.2583 - mrcnn_mask_loss: 0.5668
#  72/259 [=======>......................] - ETA: 6:35 - loss: 1.2609 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.3783 - mrcnn_class_loss: 0.0584 - mrcnn_bbox_loss: 0.2559 - mrcnn_mask_loss: 0.5628
#  73/259 [=======>......................] - ETA: 6:30 - loss: 1.2500 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.3742 - mrcnn_class_loss: 0.0580 - mrcnn_bbox_loss: 0.2535 - mrcnn_mask_loss: 0.5588
#  74/259 [=======>......................] - ETA: 6:26 - loss: 1.2390 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.3700 - mrcnn_class_loss: 0.0576 - mrcnn_bbox_loss: 0.2510 - mrcnn_mask_loss: 0.5549
#  75/259 [=======>......................] - ETA: 6:21 - loss: 1.2281 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.3657 - mrcnn_class_loss: 0.0572 - mrcnn_bbox_loss: 0.2486 - mrcnn_mask_loss: 0.5511
#  76/259 [=======>......................] - ETA: 6:17 - loss: 1.2171 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.3616 - mrcnn_class_loss: 0.0567 - mrcnn_bbox_loss: 0.2461 - mrcnn_mask_loss: 0.5472
#  77/259 [=======>......................] - ETA: 6:13 - loss: 1.2063 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.3576 - mrcnn_class_loss: 0.0563 - mrcnn_bbox_loss: 0.2436 - mrcnn_mask_loss: 0.5434
#  78/259 [========>.....................] - ETA: 6:08 - loss: 1.1957 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.3537 - mrcnn_class_loss: 0.0559 - mrcnn_bbox_loss: 0.2412 - mrcnn_mask_loss: 0.5395
#  79/259 [========>.....................] - ETA: 6:04 - loss: 1.1850 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.3497 - mrcnn_class_loss: 0.0555 - mrcnn_bbox_loss: 0.2386 - mrcnn_mask_loss: 0.5358
#  80/259 [========>.....................] - ETA: 6:00 - loss: 1.1743 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.3457 - mrcnn_class_loss: 0.0551 - mrcnn_bbox_loss: 0.2362 - mrcnn_mask_loss: 0.5320
#  81/259 [========>.....................] - ETA: 5:56 - loss: 1.1639 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.3419 - mrcnn_class_loss: 0.0547 - mrcnn_bbox_loss: 0.2338 - mrcnn_mask_loss: 0.5282
#  82/259 [========>.....................] - ETA: 5:52 - loss: 1.1536 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.3381 - mrcnn_class_loss: 0.0543 - mrcnn_bbox_loss: 0.2314 - mrcnn_mask_loss: 0.5246
#  83/259 [========>.....................] - ETA: 5:49 - loss: 1.1435 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.3343 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.2291 - mrcnn_mask_loss: 0.5210
#  84/259 [========>.....................] - ETA: 5:45 - loss: 1.1333 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.3306 - mrcnn_class_loss: 0.0535 - mrcnn_bbox_loss: 0.2267 - mrcnn_mask_loss: 0.5173
#  85/259 [========>.....................] - ETA: 5:41 - loss: 1.1233 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.3269 - mrcnn_class_loss: 0.0531 - mrcnn_bbox_loss: 0.2244 - mrcnn_mask_loss: 0.5137
#  86/259 [========>.....................] - ETA: 5:37 - loss: 1.1135 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.3234 - mrcnn_class_loss: 0.0527 - mrcnn_bbox_loss: 0.2221 - mrcnn_mask_loss: 0.5102
#  87/259 [=========>....................] - ETA: 5:34 - loss: 1.1040 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.3199 - mrcnn_class_loss: 0.0523 - mrcnn_bbox_loss: 0.2199 - mrcnn_mask_loss: 0.5067
#  88/259 [=========>....................] - ETA: 5:30 - loss: 1.0946 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.3165 - mrcnn_class_loss: 0.0519 - mrcnn_bbox_loss: 0.2178 - mrcnn_mask_loss: 0.5033
#  89/259 [=========>....................] - ETA: 5:27 - loss: 1.1056 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.3209 - mrcnn_class_loss: 0.0522 - mrcnn_bbox_loss: 0.2261 - mrcnn_mask_loss: 0.5013
#  90/259 [=========>....................] - ETA: 5:23 - loss: 1.0961 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.3175 - mrcnn_class_loss: 0.0518 - mrcnn_bbox_loss: 0.2239 - mrcnn_mask_loss: 0.4979
#  91/259 [=========>....................] - ETA: 5:20 - loss: 1.0868 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.3141 - mrcnn_class_loss: 0.0514 - mrcnn_bbox_loss: 0.2218 - mrcnn_mask_loss: 0.4945
#  92/259 [=========>....................] - ETA: 5:17 - loss: 1.0777 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.3108 - mrcnn_class_loss: 0.0510 - mrcnn_bbox_loss: 0.2197 - mrcnn_mask_loss: 0.4912
#  93/259 [=========>....................] - ETA: 5:13 - loss: 1.0688 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.3076 - mrcnn_class_loss: 0.0506 - mrcnn_bbox_loss: 0.2176 - mrcnn_mask_loss: 0.4879
#  94/259 [=========>....................] - ETA: 5:10 - loss: 1.0599 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.3045 - mrcnn_class_loss: 0.0502 - mrcnn_bbox_loss: 0.2156 - mrcnn_mask_loss: 0.4846
#  95/259 [==========>...................] - ETA: 5:07 - loss: 1.0512 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.3014 - mrcnn_class_loss: 0.0499 - mrcnn_bbox_loss: 0.2137 - mrcnn_mask_loss: 0.4814
#  96/259 [==========>...................] - ETA: 5:04 - loss: 1.0427 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.2983 - mrcnn_class_loss: 0.0495 - mrcnn_bbox_loss: 0.2117 - mrcnn_mask_loss: 0.4782
#  97/259 [==========>...................] - ETA: 5:01 - loss: 1.0343 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.2954 - mrcnn_class_loss: 0.0492 - mrcnn_bbox_loss: 0.2098 - mrcnn_mask_loss: 0.4750
#  98/259 [==========>...................] - ETA: 4:58 - loss: 1.0411 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.2987 - mrcnn_class_loss: 0.0495 - mrcnn_bbox_loss: 0.2143 - mrcnn_mask_loss: 0.4737
#  99/259 [==========>...................] - ETA: 4:55 - loss: 1.0465 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.3017 - mrcnn_class_loss: 0.0498 - mrcnn_bbox_loss: 0.2177 - mrcnn_mask_loss: 0.4723
# 100/259 [==========>...................] - ETA: 4:52 - loss: 1.0496 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.3041 - mrcnn_class_loss: 0.0500 - mrcnn_bbox_loss: 0.2197 - mrcnn_mask_loss: 0.4709
# 101/259 [==========>...................] - ETA: 4:49 - loss: 1.0514 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.3057 - mrcnn_class_loss: 0.0502 - mrcnn_bbox_loss: 0.2212 - mrcnn_mask_loss: 0.4695
# 102/259 [==========>...................] - ETA: 4:46 - loss: 1.0521 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.3063 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.2228 - mrcnn_mask_loss: 0.4679
# 103/259 [==========>...................] - ETA: 4:43 - loss: 1.0521 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.3063 - mrcnn_class_loss: 0.0504 - mrcnn_bbox_loss: 0.2243 - mrcnn_mask_loss: 0.4662
# 104/259 [===========>..................] - ETA: 4:40 - loss: 1.0510 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.3061 - mrcnn_class_loss: 0.0505 - mrcnn_bbox_loss: 0.2251 - mrcnn_mask_loss: 0.4645
# 105/259 [===========>..................] - ETA: 4:38 - loss: 1.0490 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.3059 - mrcnn_class_loss: 0.0505 - mrcnn_bbox_loss: 0.2251 - mrcnn_mask_loss: 0.4628
# 106/259 [===========>..................] - ETA: 4:35 - loss: 1.0467 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.3055 - mrcnn_class_loss: 0.0505 - mrcnn_bbox_loss: 0.2250 - mrcnn_mask_loss: 0.4609
# 107/259 [===========>..................] - ETA: 4:32 - loss: 1.0441 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.3050 - mrcnn_class_loss: 0.0504 - mrcnn_bbox_loss: 0.2250 - mrcnn_mask_loss: 0.4590
# 108/259 [===========>..................] - ETA: 4:29 - loss: 1.0411 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.3041 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.2248 - mrcnn_mask_loss: 0.4571
# 109/259 [===========>..................] - ETA: 4:27 - loss: 1.0376 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.3031 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.2244 - mrcnn_mask_loss: 0.4553
# 110/259 [===========>..................] - ETA: 4:24 - loss: 1.0339 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.3017 - mrcnn_class_loss: 0.0504 - mrcnn_bbox_loss: 0.2238 - mrcnn_mask_loss: 0.4534
# 111/259 [===========>..................] - ETA: 4:22 - loss: 1.0301 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.3002 - mrcnn_class_loss: 0.0505 - mrcnn_bbox_loss: 0.2233 - mrcnn_mask_loss: 0.4514
# 112/259 [===========>..................] - ETA: 4:19 - loss: 1.0261 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.2988 - mrcnn_class_loss: 0.0506 - mrcnn_bbox_loss: 0.2226 - mrcnn_mask_loss: 0.4495
# 113/259 [============>.................] - ETA: 4:16 - loss: 1.0219 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.2973 - mrcnn_class_loss: 0.0507 - mrcnn_bbox_loss: 0.2218 - mrcnn_mask_loss: 0.4475
# 114/259 [============>.................] - ETA: 4:14 - loss: 1.0176 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.2957 - mrcnn_class_loss: 0.0506 - mrcnn_bbox_loss: 0.2211 - mrcnn_mask_loss: 0.4455
# 115/259 [============>.................] - ETA: 4:11 - loss: 1.0129 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2940 - mrcnn_class_loss: 0.0506 - mrcnn_bbox_loss: 0.2202 - mrcnn_mask_loss: 0.4435
# 116/259 [============>.................] - ETA: 4:09 - loss: 1.0079 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2922 - mrcnn_class_loss: 0.0506 - mrcnn_bbox_loss: 0.2191 - mrcnn_mask_loss: 0.4415
# 117/259 [============>.................] - ETA: 4:06 - loss: 1.0029 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2903 - mrcnn_class_loss: 0.0505 - mrcnn_bbox_loss: 0.2181 - mrcnn_mask_loss: 0.4395
# 118/259 [============>.................] - ETA: 4:04 - loss: 0.9978 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2884 - mrcnn_class_loss: 0.0504 - mrcnn_bbox_loss: 0.2170 - mrcnn_mask_loss: 0.4375
# 119/259 [============>.................] - ETA: 4:01 - loss: 0.9924 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2864 - mrcnn_class_loss: 0.0503 - mrcnn_bbox_loss: 0.2158 - mrcnn_mask_loss: 0.4355
# 120/259 [============>.................] - ETA: 3:59 - loss: 0.9871 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2844 - mrcnn_class_loss: 0.0501 - mrcnn_bbox_loss: 0.2147 - mrcnn_mask_loss: 0.4335
# 121/259 [=============>................] - ETA: 3:57 - loss: 0.9817 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2822 - mrcnn_class_loss: 0.0500 - mrcnn_bbox_loss: 0.2135 - mrcnn_mask_loss: 0.4316
# 122/259 [=============>................] - ETA: 3:54 - loss: 0.9761 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2801 - mrcnn_class_loss: 0.0499 - mrcnn_bbox_loss: 0.2122 - mrcnn_mask_loss: 0.4296
# 123/259 [=============>................] - ETA: 3:52 - loss: 0.9705 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2780 - mrcnn_class_loss: 0.0497 - mrcnn_bbox_loss: 0.2109 - mrcnn_mask_loss: 0.4275
# 124/259 [=============>................] - ETA: 3:50 - loss: 0.9648 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.2759 - mrcnn_class_loss: 0.0495 - mrcnn_bbox_loss: 0.2096 - mrcnn_mask_loss: 0.4255
# 125/259 [=============>................] - ETA: 3:47 - loss: 0.9593 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.2738 - mrcnn_class_loss: 0.0493 - mrcnn_bbox_loss: 0.2083 - mrcnn_mask_loss: 0.4236
# 126/259 [=============>................] - ETA: 3:45 - loss: 0.9536 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.2717 - mrcnn_class_loss: 0.0491 - mrcnn_bbox_loss: 0.2069 - mrcnn_mask_loss: 0.4215
# 127/259 [=============>................] - ETA: 3:43 - loss: 0.9480 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.2697 - mrcnn_class_loss: 0.0489 - mrcnn_bbox_loss: 0.2056 - mrcnn_mask_loss: 0.4195
# 128/259 [=============>................] - ETA: 3:40 - loss: 0.9425 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.2677 - mrcnn_class_loss: 0.0487 - mrcnn_bbox_loss: 0.2043 - mrcnn_mask_loss: 0.4175
# 129/259 [=============>................] - ETA: 3:38 - loss: 0.9370 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2657 - mrcnn_class_loss: 0.0485 - mrcnn_bbox_loss: 0.2030 - mrcnn_mask_loss: 0.4155
# 130/259 [==============>...............] - ETA: 3:36 - loss: 0.9315 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2638 - mrcnn_class_loss: 0.0483 - mrcnn_bbox_loss: 0.2017 - mrcnn_mask_loss: 0.4134
# 131/259 [==============>...............] - ETA: 3:34 - loss: 0.9260 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2618 - mrcnn_class_loss: 0.0481 - mrcnn_bbox_loss: 0.2004 - mrcnn_mask_loss: 0.4114
# 132/259 [==============>...............] - ETA: 3:32 - loss: 0.9205 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2599 - mrcnn_class_loss: 0.0479 - mrcnn_bbox_loss: 0.1991 - mrcnn_mask_loss: 0.4094
# 133/259 [==============>...............] - ETA: 3:29 - loss: 0.9150 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2580 - mrcnn_class_loss: 0.0477 - mrcnn_bbox_loss: 0.1978 - mrcnn_mask_loss: 0.4074
# 134/259 [==============>...............] - ETA: 3:27 - loss: 0.9097 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.2562 - mrcnn_class_loss: 0.0475 - mrcnn_bbox_loss: 0.1965 - mrcnn_mask_loss: 0.4054
# 135/259 [==============>...............] - ETA: 3:25 - loss: 0.9043 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.2543 - mrcnn_class_loss: 0.0473 - mrcnn_bbox_loss: 0.1952 - mrcnn_mask_loss: 0.4034
# 136/259 [==============>...............] - ETA: 3:23 - loss: 0.8990 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.2525 - mrcnn_class_loss: 0.0471 - mrcnn_bbox_loss: 0.1939 - mrcnn_mask_loss: 0.4014
# 137/259 [==============>...............] - ETA: 3:21 - loss: 0.8937 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.2507 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.1927 - mrcnn_mask_loss: 0.3994
# 138/259 [==============>...............] - ETA: 3:19 - loss: 0.8885 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.2490 - mrcnn_class_loss: 0.0467 - mrcnn_bbox_loss: 0.1914 - mrcnn_mask_loss: 0.3974
# 139/259 [===============>..............] - ETA: 3:17 - loss: 0.8833 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2472 - mrcnn_class_loss: 0.0465 - mrcnn_bbox_loss: 0.1902 - mrcnn_mask_loss: 0.3954
# 140/259 [===============>..............] - ETA: 3:15 - loss: 0.8889 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2507 - mrcnn_class_loss: 0.0464 - mrcnn_bbox_loss: 0.1923 - mrcnn_mask_loss: 0.3955
# 141/259 [===============>..............] - ETA: 3:13 - loss: 0.8838 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2490 - mrcnn_class_loss: 0.0462 - mrcnn_bbox_loss: 0.1912 - mrcnn_mask_loss: 0.3934
# 142/259 [===============>..............] - ETA: 3:11 - loss: 0.8788 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2473 - mrcnn_class_loss: 0.0459 - mrcnn_bbox_loss: 0.1901 - mrcnn_mask_loss: 0.3915
# 143/259 [===============>..............] - ETA: 3:09 - loss: 0.8737 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2456 - mrcnn_class_loss: 0.0457 - mrcnn_bbox_loss: 0.1890 - mrcnn_mask_loss: 0.3895
# 144/259 [===============>..............] - ETA: 3:07 - loss: 0.8687 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2439 - mrcnn_class_loss: 0.0454 - mrcnn_bbox_loss: 0.1879 - mrcnn_mask_loss: 0.3875
# 145/259 [===============>..............] - ETA: 3:05 - loss: 0.8638 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2423 - mrcnn_class_loss: 0.0452 - mrcnn_bbox_loss: 0.1867 - mrcnn_mask_loss: 0.3856
# 146/259 [===============>..............] - ETA: 3:03 - loss: 0.8679 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2453 - mrcnn_class_loss: 0.0451 - mrcnn_bbox_loss: 0.1881 - mrcnn_mask_loss: 0.3855
# 147/259 [================>.............] - ETA: 3:01 - loss: 0.8715 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2482 - mrcnn_class_loss: 0.0450 - mrcnn_bbox_loss: 0.1891 - mrcnn_mask_loss: 0.3853
# 148/259 [================>.............] - ETA: 2:59 - loss: 0.8743 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2508 - mrcnn_class_loss: 0.0449 - mrcnn_bbox_loss: 0.1899 - mrcnn_mask_loss: 0.3848
# 149/259 [================>.............] - ETA: 2:57 - loss: 0.8764 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2531 - mrcnn_class_loss: 0.0448 - mrcnn_bbox_loss: 0.1903 - mrcnn_mask_loss: 0.3842
# 150/259 [================>.............] - ETA: 2:55 - loss: 0.8774 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2550 - mrcnn_class_loss: 0.0446 - mrcnn_bbox_loss: 0.1904 - mrcnn_mask_loss: 0.3834
# 151/259 [================>.............] - ETA: 2:53 - loss: 0.8779 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2564 - mrcnn_class_loss: 0.0446 - mrcnn_bbox_loss: 0.1904 - mrcnn_mask_loss: 0.3826
# 152/259 [================>.............] - ETA: 2:51 - loss: 0.8777 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2574 - mrcnn_class_loss: 0.0444 - mrcnn_bbox_loss: 0.1902 - mrcnn_mask_loss: 0.3816
# 153/259 [================>.............] - ETA: 2:49 - loss: 0.8770 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2580 - mrcnn_class_loss: 0.0443 - mrcnn_bbox_loss: 0.1901 - mrcnn_mask_loss: 0.3806
# 154/259 [================>.............] - ETA: 2:47 - loss: 0.8757 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2582 - mrcnn_class_loss: 0.0443 - mrcnn_bbox_loss: 0.1897 - mrcnn_mask_loss: 0.3795
# 155/259 [================>.............] - ETA: 2:45 - loss: 0.8738 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2582 - mrcnn_class_loss: 0.0441 - mrcnn_bbox_loss: 0.1891 - mrcnn_mask_loss: 0.3784
# 156/259 [=================>............] - ETA: 2:43 - loss: 0.8716 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2578 - mrcnn_class_loss: 0.0440 - mrcnn_bbox_loss: 0.1886 - mrcnn_mask_loss: 0.3773
# 157/259 [=================>............] - ETA: 2:41 - loss: 0.8690 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2572 - mrcnn_class_loss: 0.0439 - mrcnn_bbox_loss: 0.1879 - mrcnn_mask_loss: 0.3761
# 158/259 [=================>............] - ETA: 2:39 - loss: 0.8662 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2564 - mrcnn_class_loss: 0.0437 - mrcnn_bbox_loss: 0.1872 - mrcnn_mask_loss: 0.3749
# 159/259 [=================>............] - ETA: 2:38 - loss: 0.8634 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2556 - mrcnn_class_loss: 0.0436 - mrcnn_bbox_loss: 0.1865 - mrcnn_mask_loss: 0.3737
# 160/259 [=================>............] - ETA: 2:36 - loss: 0.8603 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2547 - mrcnn_class_loss: 0.0435 - mrcnn_bbox_loss: 0.1857 - mrcnn_mask_loss: 0.3725
# 161/259 [=================>............] - ETA: 2:34 - loss: 0.8572 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.2537 - mrcnn_class_loss: 0.0434 - mrcnn_bbox_loss: 0.1850 - mrcnn_mask_loss: 0.3712
# 162/259 [=================>............] - ETA: 2:32 - loss: 0.8542 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2527 - mrcnn_class_loss: 0.0433 - mrcnn_bbox_loss: 0.1843 - mrcnn_mask_loss: 0.3699
# 163/259 [=================>............] - ETA: 2:30 - loss: 0.8510 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2517 - mrcnn_class_loss: 0.0432 - mrcnn_bbox_loss: 0.1836 - mrcnn_mask_loss: 0.3686
# 164/259 [=================>............] - ETA: 2:28 - loss: 0.8476 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2505 - mrcnn_class_loss: 0.0431 - mrcnn_bbox_loss: 0.1827 - mrcnn_mask_loss: 0.3673
# 165/259 [==================>...........] - ETA: 2:27 - loss: 0.8441 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2493 - mrcnn_class_loss: 0.0430 - mrcnn_bbox_loss: 0.1819 - mrcnn_mask_loss: 0.3660
# 166/259 [==================>...........] - ETA: 2:25 - loss: 0.8406 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2481 - mrcnn_class_loss: 0.0429 - mrcnn_bbox_loss: 0.1810 - mrcnn_mask_loss: 0.3646
# 167/259 [==================>...........] - ETA: 2:23 - loss: 0.8370 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2468 - mrcnn_class_loss: 0.0428 - mrcnn_bbox_loss: 0.1802 - mrcnn_mask_loss: 0.3633
# 168/259 [==================>...........] - ETA: 2:21 - loss: 0.8333 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2455 - mrcnn_class_loss: 0.0427 - mrcnn_bbox_loss: 0.1793 - mrcnn_mask_loss: 0.3619
# 169/259 [==================>...........] - ETA: 2:19 - loss: 0.8296 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2442 - mrcnn_class_loss: 0.0426 - mrcnn_bbox_loss: 0.1784 - mrcnn_mask_loss: 0.3606
# 170/259 [==================>...........] - ETA: 2:18 - loss: 0.8260 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2429 - mrcnn_class_loss: 0.0425 - mrcnn_bbox_loss: 0.1775 - mrcnn_mask_loss: 0.3592
# 171/259 [==================>...........] - ETA: 2:16 - loss: 0.8223 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.2416 - mrcnn_class_loss: 0.0423 - mrcnn_bbox_loss: 0.1766 - mrcnn_mask_loss: 0.3579
# 172/259 [==================>...........] - ETA: 2:14 - loss: 0.8186 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2403 - mrcnn_class_loss: 0.0422 - mrcnn_bbox_loss: 0.1758 - mrcnn_mask_loss: 0.3565
# 173/259 [===================>..........] - ETA: 2:12 - loss: 0.8149 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2390 - mrcnn_class_loss: 0.0420 - mrcnn_bbox_loss: 0.1749 - mrcnn_mask_loss: 0.3551
# 174/259 [===================>..........] - ETA: 2:11 - loss: 0.8112 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2378 - mrcnn_class_loss: 0.0419 - mrcnn_bbox_loss: 0.1740 - mrcnn_mask_loss: 0.3538
# 175/259 [===================>..........] - ETA: 2:09 - loss: 0.8075 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2365 - mrcnn_class_loss: 0.0417 - mrcnn_bbox_loss: 0.1731 - mrcnn_mask_loss: 0.3524
# 176/259 [===================>..........] - ETA: 2:07 - loss: 0.8039 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2352 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1723 - mrcnn_mask_loss: 0.3510
# 177/259 [===================>..........] - ETA: 2:05 - loss: 0.8003 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2340 - mrcnn_class_loss: 0.0414 - mrcnn_bbox_loss: 0.1714 - mrcnn_mask_loss: 0.3497
# 178/259 [===================>..........] - ETA: 2:04 - loss: 0.7967 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2327 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1706 - mrcnn_mask_loss: 0.3483
# 179/259 [===================>..........] - ETA: 2:02 - loss: 0.7930 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.2315 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1697 - mrcnn_mask_loss: 0.3470
# 180/259 [===================>..........] - ETA: 2:00 - loss: 0.7895 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2302 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1689 - mrcnn_mask_loss: 0.3457
# 181/259 [===================>..........] - ETA: 1:59 - loss: 0.7860 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2290 - mrcnn_class_loss: 0.0409 - mrcnn_bbox_loss: 0.1680 - mrcnn_mask_loss: 0.3444
# 182/259 [====================>.........] - ETA: 1:57 - loss: 0.7825 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2278 - mrcnn_class_loss: 0.0407 - mrcnn_bbox_loss: 0.1672 - mrcnn_mask_loss: 0.3430
# 183/259 [====================>.........] - ETA: 1:55 - loss: 0.7790 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2266 - mrcnn_class_loss: 0.0406 - mrcnn_bbox_loss: 0.1664 - mrcnn_mask_loss: 0.3417
# 184/259 [====================>.........] - ETA: 1:54 - loss: 0.7755 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2254 - mrcnn_class_loss: 0.0405 - mrcnn_bbox_loss: 0.1655 - mrcnn_mask_loss: 0.3404
# 185/259 [====================>.........] - ETA: 1:52 - loss: 0.7720 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2242 - mrcnn_class_loss: 0.0403 - mrcnn_bbox_loss: 0.1647 - mrcnn_mask_loss: 0.3391
# 186/259 [====================>.........] - ETA: 1:50 - loss: 0.7685 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2230 - mrcnn_class_loss: 0.0402 - mrcnn_bbox_loss: 0.1639 - mrcnn_mask_loss: 0.3378
# 187/259 [====================>.........] - ETA: 1:49 - loss: 0.7651 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.2218 - mrcnn_class_loss: 0.0401 - mrcnn_bbox_loss: 0.1630 - mrcnn_mask_loss: 0.3365
# 188/259 [====================>.........] - ETA: 1:47 - loss: 0.7691 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.2233 - mrcnn_class_loss: 0.0401 - mrcnn_bbox_loss: 0.1648 - mrcnn_mask_loss: 0.3372
# ...
#  68/259 [======>.......................] - ETA: 3:37 - loss: 0.2825 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0716 - mrcnn_class_loss: 0.0259 - mrcnn_bbox_loss: 0.0455 - mrcnn_mask_loss: 0.1372
#  69/259 [======>.......................] - ETA: 3:36 - loss: 0.2801 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0707 - mrcnn_class_loss: 0.0257 - mrcnn_bbox_loss: 0.0450 - mrcnn_mask_loss: 0.1364
#  70/259 [=======>......................] - ETA: 3:35 - loss: 0.2975 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0746 - mrcnn_class_loss: 0.0269 - mrcnn_bbox_loss: 0.0510 - mrcnn_mask_loss: 0.1426
#  71/259 [=======>......................] - ETA: 3:33 - loss: 0.3131 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0781 - mrcnn_class_loss: 0.0281 - mrcnn_bbox_loss: 0.0564 - mrcnn_mask_loss: 0.1481
#  72/259 [=======>......................] - ETA: 3:32 - loss: 0.3261 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0811 - mrcnn_class_loss: 0.0292 - mrcnn_bbox_loss: 0.0606 - mrcnn_mask_loss: 0.1527
#  73/259 [=======>......................] - ETA: 3:31 - loss: 0.3239 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0802 - mrcnn_class_loss: 0.0291 - mrcnn_bbox_loss: 0.0603 - mrcnn_mask_loss: 0.1519
#  74/259 [=======>......................] - ETA: 3:30 - loss: 0.3338 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0825 - mrcnn_class_loss: 0.0301 - mrcnn_bbox_loss: 0.0635 - mrcnn_mask_loss: 0.1552
#  75/259 [=======>......................] - ETA: 3:29 - loss: 0.3419 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0844 - mrcnn_class_loss: 0.0308 - mrcnn_bbox_loss: 0.0662 - mrcnn_mask_loss: 0.1580
#  76/259 [=======>......................] - ETA: 3:28 - loss: 0.3402 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0836 - mrcnn_class_loss: 0.0308 - mrcnn_bbox_loss: 0.0660 - mrcnn_mask_loss: 0.1572
#  77/259 [=======>......................] - ETA: 3:27 - loss: 0.3459 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0850 - mrcnn_class_loss: 0.0314 - mrcnn_bbox_loss: 0.0677 - mrcnn_mask_loss: 0.1593
#  78/259 [========>.....................] - ETA: 3:26 - loss: 0.3508 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0860 - mrcnn_class_loss: 0.0319 - mrcnn_bbox_loss: 0.0692 - mrcnn_mask_loss: 0.1610
#  79/259 [========>.....................] - ETA: 3:25 - loss: 0.3548 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0869 - mrcnn_class_loss: 0.0323 - mrcnn_bbox_loss: 0.0704 - mrcnn_mask_loss: 0.1624
#  80/259 [========>.....................] - ETA: 3:23 - loss: 0.3580 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0876 - mrcnn_class_loss: 0.0325 - mrcnn_bbox_loss: 0.0715 - mrcnn_mask_loss: 0.1637
#  81/259 [========>.....................] - ETA: 3:22 - loss: 0.3606 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0881 - mrcnn_class_loss: 0.0327 - mrcnn_bbox_loss: 0.0724 - mrcnn_mask_loss: 0.1646
#  82/259 [========>.....................] - ETA: 3:21 - loss: 0.3625 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0885 - mrcnn_class_loss: 0.0327 - mrcnn_bbox_loss: 0.0730 - mrcnn_mask_loss: 0.1654
#  83/259 [========>.....................] - ETA: 3:20 - loss: 0.3641 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0888 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0734 - mrcnn_mask_loss: 0.1661
#  84/259 [========>.....................] - ETA: 3:19 - loss: 0.3653 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0889 - mrcnn_class_loss: 0.0332 - mrcnn_bbox_loss: 0.0736 - mrcnn_mask_loss: 0.1666
#  85/259 [========>.....................] - ETA: 3:17 - loss: 0.3661 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0890 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0737 - mrcnn_mask_loss: 0.1671
#  86/259 [========>.....................] - ETA: 3:16 - loss: 0.3666 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0889 - mrcnn_class_loss: 0.0336 - mrcnn_bbox_loss: 0.0736 - mrcnn_mask_loss: 0.1675
#  87/259 [=========>....................] - ETA: 3:15 - loss: 0.3666 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0888 - mrcnn_class_loss: 0.0336 - mrcnn_bbox_loss: 0.0735 - mrcnn_mask_loss: 0.1678
#  88/259 [=========>....................] - ETA: 3:14 - loss: 0.3664 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0886 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0732 - mrcnn_mask_loss: 0.1680
#  89/259 [=========>....................] - ETA: 3:13 - loss: 0.3659 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0883 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0729 - mrcnn_mask_loss: 0.1681
#  90/259 [=========>....................] - ETA: 3:12 - loss: 0.3653 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0879 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0727 - mrcnn_mask_loss: 0.1682
#  91/259 [=========>....................] - ETA: 3:11 - loss: 0.3646 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0875 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0723 - mrcnn_mask_loss: 0.1681
#  92/259 [=========>....................] - ETA: 3:09 - loss: 0.3637 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0871 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.0719 - mrcnn_mask_loss: 0.1681
#  93/259 [=========>....................] - ETA: 3:08 - loss: 0.3627 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0866 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0716 - mrcnn_mask_loss: 0.1680
#  94/259 [=========>....................] - ETA: 3:07 - loss: 0.3618 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0861 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0712 - mrcnn_mask_loss: 0.1678
#  95/259 [==========>...................] - ETA: 3:06 - loss: 0.3608 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0857 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0709 - mrcnn_mask_loss: 0.1677
#  96/259 [==========>...................] - ETA: 3:05 - loss: 0.3597 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0851 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0705 - mrcnn_mask_loss: 0.1675
#  97/259 [==========>...................] - ETA: 3:04 - loss: 0.3586 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0846 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0701 - mrcnn_mask_loss: 0.1673
#  98/259 [==========>...................] - ETA: 3:02 - loss: 0.3574 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0840 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0697 - mrcnn_mask_loss: 0.1670
#  99/259 [==========>...................] - ETA: 3:01 - loss: 0.3562 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0835 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0694 - mrcnn_mask_loss: 0.1668
# 100/259 [==========>...................] - ETA: 3:00 - loss: 0.3549 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0829 - mrcnn_class_loss: 0.0334 - mrcnn_bbox_loss: 0.0690 - mrcnn_mask_loss: 0.1665
# 101/259 [==========>...................] - ETA: 2:59 - loss: 0.3535 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0823 - mrcnn_class_loss: 0.0333 - mrcnn_bbox_loss: 0.0685 - mrcnn_mask_loss: 0.1662
# 102/259 [==========>...................] - ETA: 2:58 - loss: 0.3519 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0817 - mrcnn_class_loss: 0.0331 - mrcnn_bbox_loss: 0.0680 - mrcnn_mask_loss: 0.1658
# 103/259 [==========>...................] - ETA: 2:57 - loss: 0.3504 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0811 - mrcnn_class_loss: 0.0331 - mrcnn_bbox_loss: 0.0676 - mrcnn_mask_loss: 0.1655
# 104/259 [===========>..................] - ETA: 2:56 - loss: 0.3489 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0805 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0671 - mrcnn_mask_loss: 0.1651
# 105/259 [===========>..................] - ETA: 2:54 - loss: 0.3473 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0799 - mrcnn_class_loss: 0.0329 - mrcnn_bbox_loss: 0.0666 - mrcnn_mask_loss: 0.1647
# 106/259 [===========>..................] - ETA: 2:53 - loss: 0.3457 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0793 - mrcnn_class_loss: 0.0328 - mrcnn_bbox_loss: 0.0661 - mrcnn_mask_loss: 0.1643
# 107/259 [===========>..................] - ETA: 2:52 - loss: 0.3442 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0787 - mrcnn_class_loss: 0.0327 - mrcnn_bbox_loss: 0.0657 - mrcnn_mask_loss: 0.1639
# 108/259 [===========>..................] - ETA: 2:51 - loss: 0.3427 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0781 - mrcnn_class_loss: 0.0326 - mrcnn_bbox_loss: 0.0653 - mrcnn_mask_loss: 0.1635
# 109/259 [===========>..................] - ETA: 2:50 - loss: 0.3412 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0775 - mrcnn_class_loss: 0.0325 - mrcnn_bbox_loss: 0.0648 - mrcnn_mask_loss: 0.1631
# 110/259 [===========>..................] - ETA: 2:49 - loss: 0.3397 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0769 - mrcnn_class_loss: 0.0324 - mrcnn_bbox_loss: 0.0644 - mrcnn_mask_loss: 0.1627
# 111/259 [===========>..................] - ETA: 2:48 - loss: 0.3382 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0763 - mrcnn_class_loss: 0.0324 - mrcnn_bbox_loss: 0.0640 - mrcnn_mask_loss: 0.1622
# 112/259 [===========>..................] - ETA: 2:46 - loss: 0.3366 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0757 - mrcnn_class_loss: 0.0323 - mrcnn_bbox_loss: 0.0636 - mrcnn_mask_loss: 0.1618
# 113/259 [============>.................] - ETA: 2:45 - loss: 0.3350 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0752 - mrcnn_class_loss: 0.0322 - mrcnn_bbox_loss: 0.0631 - mrcnn_mask_loss: 0.1613
# 114/259 [============>.................] - ETA: 2:44 - loss: 0.3334 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0746 - mrcnn_class_loss: 0.0321 - mrcnn_bbox_loss: 0.0627 - mrcnn_mask_loss: 0.1608
# 115/259 [============>.................] - ETA: 2:43 - loss: 0.3483 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0786 - mrcnn_class_loss: 0.0330 - mrcnn_bbox_loss: 0.0663 - mrcnn_mask_loss: 0.1672
# 116/259 [============>.................] - ETA: 2:42 - loss: 0.3625 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0824 - mrcnn_class_loss: 0.0339 - mrcnn_bbox_loss: 0.0698 - mrcnn_mask_loss: 0.1732
# 117/259 [============>.................] - ETA: 2:41 - loss: 0.3609 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0818 - mrcnn_class_loss: 0.0338 - mrcnn_bbox_loss: 0.0694 - mrcnn_mask_loss: 0.1726
# 118/259 [============>.................] - ETA: 2:40 - loss: 0.3727 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0851 - mrcnn_class_loss: 0.0345 - mrcnn_bbox_loss: 0.0723 - mrcnn_mask_loss: 0.1774
# 119/259 [============>.................] - ETA: 2:39 - loss: 0.3834 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0882 - mrcnn_class_loss: 0.0352 - mrcnn_bbox_loss: 0.0750 - mrcnn_mask_loss: 0.1817
# 120/259 [============>.................] - ETA: 2:37 - loss: 0.3925 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0909 - mrcnn_class_loss: 0.0356 - mrcnn_bbox_loss: 0.0774 - mrcnn_mask_loss: 0.1853
# 121/259 [=============>................] - ETA: 2:36 - loss: 0.3915 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0903 - mrcnn_class_loss: 0.0354 - mrcnn_bbox_loss: 0.0772 - mrcnn_mask_loss: 0.1852
# 122/259 [=============>................] - ETA: 2:35 - loss: 0.3983 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0923 - mrcnn_class_loss: 0.0358 - mrcnn_bbox_loss: 0.0790 - mrcnn_mask_loss: 0.1878
# 123/259 [=============>................] - ETA: 2:34 - loss: 0.4040 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0939 - mrcnn_class_loss: 0.0361 - mrcnn_bbox_loss: 0.0806 - mrcnn_mask_loss: 0.1900
# 124/259 [=============>................] - ETA: 2:33 - loss: 0.4036 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0935 - mrcnn_class_loss: 0.0361 - mrcnn_bbox_loss: 0.0806 - mrcnn_mask_loss: 0.1900
# 125/259 [=============>................] - ETA: 2:32 - loss: 0.4077 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0945 - mrcnn_class_loss: 0.0362 - mrcnn_bbox_loss: 0.0818 - mrcnn_mask_loss: 0.1917
# 126/259 [=============>................] - ETA: 2:31 - loss: 0.4111 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0953 - mrcnn_class_loss: 0.0365 - mrcnn_bbox_loss: 0.0828 - mrcnn_mask_loss: 0.1930
# 127/259 [=============>................] - ETA: 2:30 - loss: 0.4138 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0959 - mrcnn_class_loss: 0.0366 - mrcnn_bbox_loss: 0.0837 - mrcnn_mask_loss: 0.1941
# 128/259 [=============>................] - ETA: 2:28 - loss: 0.4160 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0964 - mrcnn_class_loss: 0.0368 - mrcnn_bbox_loss: 0.0844 - mrcnn_mask_loss: 0.1950
# 129/259 [=============>................] - ETA: 2:27 - loss: 0.4179 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0967 - mrcnn_class_loss: 0.0370 - mrcnn_bbox_loss: 0.0850 - mrcnn_mask_loss: 0.1958
# 130/259 [==============>...............] - ETA: 2:26 - loss: 0.4192 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0968 - mrcnn_class_loss: 0.0372 - mrcnn_bbox_loss: 0.0854 - mrcnn_mask_loss: 0.1964
# 131/259 [==============>...............] - ETA: 2:25 - loss: 0.4201 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0967 - mrcnn_class_loss: 0.0374 - mrcnn_bbox_loss: 0.0857 - mrcnn_mask_loss: 0.1968
# 132/259 [==============>...............] - ETA: 2:24 - loss: 0.4207 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0965 - mrcnn_class_loss: 0.0375 - mrcnn_bbox_loss: 0.0860 - mrcnn_mask_loss: 0.1971
# 133/259 [==============>...............] - ETA: 2:23 - loss: 0.4210 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0963 - mrcnn_class_loss: 0.0375 - mrcnn_bbox_loss: 0.0862 - mrcnn_mask_loss: 0.1974
# 134/259 [==============>...............] - ETA: 2:22 - loss: 0.4211 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0960 - mrcnn_class_loss: 0.0376 - mrcnn_bbox_loss: 0.0863 - mrcnn_mask_loss: 0.1976
# 135/259 [==============>...............] - ETA: 2:21 - loss: 0.4210 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0956 - mrcnn_class_loss: 0.0377 - mrcnn_bbox_loss: 0.0863 - mrcnn_mask_loss: 0.1978
# 136/259 [==============>...............] - ETA: 2:19 - loss: 0.4208 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0953 - mrcnn_class_loss: 0.0379 - mrcnn_bbox_loss: 0.0862 - mrcnn_mask_loss: 0.1979
# 137/259 [==============>...............] - ETA: 2:18 - loss: 0.4206 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0949 - mrcnn_class_loss: 0.0380 - mrcnn_bbox_loss: 0.0861 - mrcnn_mask_loss: 0.1980
# 138/259 [==============>...............] - ETA: 2:17 - loss: 0.4200 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0945 - mrcnn_class_loss: 0.0380 - mrcnn_bbox_loss: 0.0860 - mrcnn_mask_loss: 0.1980
# 139/259 [===============>..............] - ETA: 2:16 - loss: 0.4194 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0941 - mrcnn_class_loss: 0.0379 - mrcnn_bbox_loss: 0.0858 - mrcnn_mask_loss: 0.1981
# 140/259 [===============>..............] - ETA: 2:15 - loss: 0.4187 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0937 - mrcnn_class_loss: 0.0379 - mrcnn_bbox_loss: 0.0855 - mrcnn_mask_loss: 0.1980
# 141/259 [===============>..............] - ETA: 2:14 - loss: 0.4179 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0932 - mrcnn_class_loss: 0.0379 - mrcnn_bbox_loss: 0.0852 - mrcnn_mask_loss: 0.1979
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ae96d24339a8> in <module>
#       5     job_name    = job_name,
#       6     wait        = True,
# ----> 7     logs        = 'All'
#       8 )
#
# ~/.virtualenvs/tf_1.14.0/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     680         self.jobs.append(self.latest_training_job)
#     681         if wait:
# --> 682             self.latest_training_job.wait(logs=logs)
#     683
#     684     def _compilation_job_name(self):
#
# ~/.virtualenvs/tf_1.14.0/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1623         # If logs are requested, call logs_for_jobs.
#    1624         if logs != "None":
# -> 1625             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1626         else:
#    1627             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/.virtualenvs/tf_1.14.0/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3629                 break
#    3630
# -> 3631             time.sleep(poll)
#    3632
#    3633             if state == LogState.JOB_COMPLETE:
#
# KeyboardInterrupt:
