# %% [markdown]
# ## Sagemaker container lesion example
# In this example is launched a dummy container using spot instances, to test what's the behavior of the aws Sagemaker with docker containers, and what's the behaviour of the container whene it is terminated by aws due to lack of spot resources.</p>
# <p>In this example is simulated by a dummy python script (into the container) that performs similar actions that a normal training script with tensorflow or other framework should do, more specificaly:
#
# - Fake checkpoints are written in txt format in the folder `/opt/ml/checkpoints/`.
#
# - Fake tensorboard records are written every 20 seconds into the folder `/opt/ml/output/tensorboard/`, for check the real-time prensence into the s3 bucket folder  specified.
#
# - Furthermore the tree command is executed in the path `/opt/ml/` for inspect the folder structure created by sagemaker, and the result is stored in the `/opt/output/data/` folder as a txt file.

# %%
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.debugger import TensorBoardOutputConfig

# %% [markdown]
# In this section is recovered the Sagemaker bucket generated by default from the service

# %%
# default sagemaker bucket name request 
sagemaker_session = sagemaker.session.Session()
sagemaker_default_bucket = sagemaker_session.default_bucket()

print("bucket generated by sagemacker:" + sagemaker_default_bucket)
# Out:
# bucket generated by sagemacker:sagemaker-eu-west-1-011827850615

# %%
############################  JOB NAME  ####################################

# job-name definition:
# every multi-job session of training jobs is characterized by a base-job-name
# the job-name on the contrary is the identifier of the single training job.
# The job-name must be different for each training job and should be used to
# divide the results of different training jobs into specific folders.
job_name = 'test-21'

# %% [markdown]
# ## Defining the s3 bucket for the training job
# In this section are defined all the nedeed variables that specify the paths to s3 buckets for the inputs and outputs data.
#
# It's worth spending a few words about the configuration of the TensorBoardOutputConfig, this path can be used for tensorboard data if you use tensorflow or for other types of files that is important for you to take out of the container during the training process. in this example we write some txt files filled with random chearacters in the `container_local_output_path` and this files became available in the `s3_output_path` relative to the TensorBoardOutputConfig in a few seconds.

# %%
############################   INPUTS  ####################################

# repositroy ECR containing the docker image configured to be executed by Sagemaker
# ecr_container_uri = "<your aws id>.dkr.ecr.<your aws region>.amazonaws.com/<your repo name:your repo tag>"
ecr_container_uri = "011827850615.dkr.ecr.eu-west-1.amazonaws.com/maskrcnn_repo_test:lesion"
#ecr_container_uri = "011827850615.dkr.ecr.eu-west-1.amazonaws.com/maskrcnn_repo_test:lesion_2"

# s3 path containing the dataset needed for training the model
dataset_bucket = "s3://datsetsbucket/isic2018/"

# s3 path containing the model with pretrained weights, in the next example in this folder would be
# stored the Mask R-CNN model trained on COCO. 
model_bucket = 's3://cermodelbucket'

############################  OUTPUTS  ####################################

# s3 path where are stored the results of the instance profiler and any other data saved during the training in the folder /opt/ml/output/data/
output_path = f's3://{sagemaker_default_bucket}/output'

# s3 path where are stored the checkpoints of the training proces
checkpoints_path = f'{output_path}/{job_name}/checkpoints'

# internal paths for checkpoints and tenorboard logs passed to the container as env variables
user_defined_env_vars = {"checkpoints": "/opt/ml/checkpoints",
                        "tensorboard": "/opt/ml/output/tensorboard"}

# Definition of s3 target bucket folder for the tensorboard outputs and container folder where the tensorboard record must to be placed.
# it's possible to place the tensorboard output in other places but sagemaker copy that records into '/opt/ml/output/tensorboard' so we decide to
# put the records directly in there.
# Note: in the path 's3://testtflogs/logs' the recors are divided into folders related to the job-name in this example the output of tensorboard
# should be fine in 's3://testtflogs/logs/test-11'
tensorboard_output_config = TensorBoardOutputConfig(
    s3_output_path='s3://testtflogs/logs',
    container_local_output_path=user_defined_env_vars['tensorboard']
)

# %% [markdown]
# In this section are recovered the execution role ARN associated to this notebook, that will be passed to the estimator for launching the training job, be sure to give permissions to use other buckets to this role, otherwise it will only be possible to use buckets starting with the sagemaker keyword, in this case the permission is needed.

# %%
# if you are running the code from jupiter
# getting the execution role of this instance of sagemaker notebook
# role = get_execution_role()
# print(role)

# if you are running the code from local
role = 'arn:aws:iam::011827850615:role/service-role/AmazonSageMaker-ExecutionRole-20210522T125188'
# role = 'arn:aws:iam::<your aws id>:role/service-role/<your role name>'

# %% [markdown]
# In this section are defined the hyperparameters, this values are passed to the estimator definitions and would be reachable from the trainning script in the container as commandline arguments, or like environment variables whit this notation `SM_HP_{hyperparameter_name}`, es. `SM_HP_HP1` or `SM_HP_BATCH` in this case

# %%
# hyperparameters definition
hyperparameters = {
    "NAME": "lesion", 
    "GPU_COUNT": 1, 
    "IMAGES_PER_GPU": 2,
    "CLASS_NAMES": "{\"1\": \"lesion\"}",
    "TRAINING_SPLIT": 0.8,
    "HEAD_TRAIN_EPOCHS": 20,
    "ALL_TRAIN_EPOCHS": 40
}

# %% [markdown]
# ## Setup the training job
# This is the key function of the script, in there are configured al the training job parameters, are passed all the path that was defined earlier, the hyperparameters and are defined many settings relative to the type of machine used for the job, and in witch mode should run.
#
# More specificaly we chose to run in spot mode (`use_spot_instances = True`), in this mode the cost of the training goes down from 50% to 80% depending on the instance type chosen and by the availability of the machine, this mode enable aws to sell at lower price unused compute capability in the cloud and can stop your application if someone need this machine in on-demand mode (without any discount).
#
# Whene you chose to run in spot mode two more variables should be set, `max_run` and `max_wait`, this variables specify how match time in seconds the container could run and the second specify in the case that it will be stoped by aws how much time the program should wait that spot instances became available again for restart your container, if one of the two limits are exceeded the training job will be terminated.
#
# For other info about the parameters of this function you can check the [reference](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html)

# %%
training_test = sagemaker.estimator.Estimator(
    # container image 
    image_uri    = ecr_container_uri, 
    # role of sagemaker notebook instance
    role         = role, 
    # number of instance to launch
    instance_count = 1, 
    # if you want to use local mode
    #train_instance_type="local",  
    # type of instance in witch place the training job
    #instance_type = 'ml.g4dn.2xlarge',
    instance_type = 'ml.p3.2xlarge',
    # space in GB of the storage attached to the ec2 instance
    volume_size  = 50,
    # max number of seconds of running for the job until the termination of the process
    max_run      = 10*3600,
    # s3 path where will be placed the results of the profiler and the content of /opt/ml/output/data/ path as tar.gz file 
    output_path  = output_path, 
    # prefix for the trainng job name, if not specified generated automatically
    #base_job_name="training-test", 
    # training job hyperparameters, parameters passed as command line arguments
    hyperparameters = hyperparameters, 
    # list of tags for the job
    tags = [{"Key": "CER", "Value": "1"},],
    # s3 path where to find the data needed for the start of the training job like the pretrained model,and that will be copied into the folder /opt/ml/inputs/data/model (sovrascrivibile da model_channel_name)
    model_uri    = model_bucket, 
    # name of the chanel where will be saved the data included in the path model_uri (/opt/ml/inputs/data/<model_channel_name>)
    model_channel_name = 'model', 
    # dict regexs for metrics extraction from stdout {"<metric name>":"<regex for logs estraction>", ...}
    #metric_definitions = , 
    # flag for enabling the spot training
    use_spot_instances = True, 
    # max time of waiting for spot instance to became available again
    max_wait = 24*3600, 
    # s3 chekpoints target path
    checkpoint_s3_uri = checkpoints_path, 
    # default: '/opt/ml/checkpoints'
    checkpoint_local_path = user_defined_env_vars['checkpoints'], 
    # SageMaker Debugger rules
    #rules = ; 
    # Tensorboard output configuration
    tensorboard_output_config = tensorboard_output_config,
    # dict usefull for setting more environment variables into the container
    environment = user_defined_env_vars,
    # max number of try to restart the job if it's finish unespectedly
    #max_retry_attempts =   
)

# %% [markdown]
# ## Launching the training job
# In this section of the notebook the training-job start, using the `.fit()` method of estimator object.
#
# This method have the input parameter that could be defined as a dict with a key and a path to local storage or s3 bucket where are present files that we would download to the container, note that the number of path that could be specified are not limited and for each input path in the container into `/opt/ml/inputs/` is created one folder with the name equal to the passed key name and containing the data into the argument path. In this case we only passed one path to input param and we have as a result `/opt/ml/inputs/dataset/` into the container filled with the same data placed into `dataset_bucket ='s3://datsetsbucket/isic2018/test_dataset/'`, if you pass this dict with more values the result will be an `inputs/` folder populated with more subfolders and relative data.
#
# The `job_name` is a very important parameter this enable you to distinguish from different jobs launched simultaniously or in different moments and permit to distinguish the training job in the training job panel for this reason they can't have the same name, if you launch two training job with the same name the result is an error and the container dosen't start.
#
# Another note is relative to wait and logs parameters, this parameters enable you to watch the logs relative to the startup of the machine and to watch the training job machine logs outputs at the end of the training process (it's not possible to see the training job stdout in real-time). With this configuration the function fit don't terminate until the job isn't finished, but if you don't enable the wait parameter the job start and fit function terminate so you can launch other functions or other jobs,  so to see the logs the wait param should be true.
#
# If something is unclear you can check the relative [reference](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html)

# %%
training_test.fit(
    inputs      = {
        'dataset': dataset_bucket
    },
    job_name    = job_name,
    wait        = True,
    logs        = 'All'
)
# Out:
# 2021-05-29 20:14:55 Starting - Starting the training job...ProfilerReport-1622319294: InProgress
# ...
# 2021-05-29 20:15:49 Starting - Launching requested ML instances......
# 2021-05-29 20:16:49 Starting - Preparing the instances for training......
# 2021-05-29 20:18:00 Downloading - Downloading input data............
# 2021-05-29 20:19:50 Training - Downloading the training image...........2021-05-29 20:21:51,242 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-29 20:21:57,500 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-29 20:21:57,522 sagemaker-training-toolkit INFO     Failed to parse hyperparameter NAME value lesion to Json.
# Returning the value itself
# 2021-05-29 20:21:57,533 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "model": "/opt/ml/input/data/model",
#         "dataset": "/opt/ml/input/data/dataset"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "ALL_TRAIN_EPOCHS": 40,
#         "GPU_COUNT": 1,
#         "HEAD_TRAIN_EPOCHS": 20,
#         "CLASS_NAMES": {
#             "1": "lesion"
#         },
#         "IMAGES_PER_GPU": 2,
#         "TRAINING_SPLIT": 0.8,
#         "NAME": "lesion"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "model": {
#             "ContentType": "application/x-sagemaker-model",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "dataset": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "test-21",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "lesions_sagemaker",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "lesions_sagemaker.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"ALL_TRAIN_EPOCHS":40,"CLASS_NAMES":{"1":"lesion"},"GPU_COUNT":1,"HEAD_TRAIN_EPOCHS":20,"IMAGES_PER_GPU":2,"NAME":"lesion","TRAINING_SPLIT":0.8}
# SM_USER_ENTRY_POINT=lesions_sagemaker.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"dataset":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["dataset","model"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=lesions_sagemaker
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"dataset":"/opt/ml/input/data/dataset","model":"/opt/ml/input/data/model"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"ALL_TRAIN_EPOCHS":40,"CLASS_NAMES":{"1":"lesion"},"GPU_COUNT":1,"HEAD_TRAIN_EPOCHS":20,"IMAGES_PER_GPU":2,"NAME":"lesion","TRAINING_SPLIT":0.8},"input_config_dir":"/opt/ml/input/config","input_data_config":{"dataset":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"test-21","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"lesions_sagemaker","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"lesions_sagemaker.py"}
# SM_USER_ARGS=["--ALL_TRAIN_EPOCHS","40","--CLASS_NAMES","1=lesion","--GPU_COUNT","1","--HEAD_TRAIN_EPOCHS","20","--IMAGES_PER_GPU","2","--NAME","lesion","--TRAINING_SPLIT","0.8"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_MODEL=/opt/ml/input/data/model
# SM_CHANNEL_DATASET=/opt/ml/input/data/dataset
# SM_HP_ALL_TRAIN_EPOCHS=40
# SM_HP_GPU_COUNT=1
# SM_HP_HEAD_TRAIN_EPOCHS=20
# SM_HP_CLASS_NAMES={"1":"lesion"}
# SM_HP_IMAGES_PER_GPU=2
# SM_HP_TRAINING_SPLIT=0.8
# SM_HP_NAME=lesion
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 lesions_sagemaker.py --ALL_TRAIN_EPOCHS 40 --CLASS_NAMES 1=lesion --GPU_COUNT 1 --HEAD_TRAIN_EPOCHS 20 --IMAGES_PER_GPU 2 --NAME lesion --TRAINING_SPLIT 0.8
#
#
#
# 2021-05-29 20:22:10 Training - Training image download completed. Training in progress.training samples:2075
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# validations samples:519
#
# Configurations:
# ALL_TRAIN_EPOCHS               40
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# CLASS_NAMES                    {'1': 'lesion'}
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# HEAD_TRAIN_EPOCHS              20
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           lesion
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1037
# TOP_DOWN_PYRAMID_SIZE          256
# TRAINING_SPLIT                 0.8
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               259
# WEIGHT_DECAY                   0.0001
#
#
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /opt/ml/checkpoints/lesion20210529T2022/mask_rcnn_lesion_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/20
#    1/1037 [..............................] - ETA: 14:00:37 - loss: 4.4695 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4907 - mrcnn_class_loss: 1.4753 - mrcnn_bbox_loss: 1.0424 - mrcnn_mask_loss: 1.4540
#    2/1037 [..............................] - ETA: 7:03:07 - loss: 4.0842 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4869 - mrcnn_class_loss: 1.1275 - mrcnn_bbox_loss: 1.0337 - mrcnn_mask_loss: 1.4290
#    3/1037 [..............................] - ETA: 4:44:08 - loss: 3.7168 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4799 - mrcnn_class_loss: 0.8299 - mrcnn_bbox_loss: 0.9956 - mrcnn_mask_loss: 1.4044
#    4/1037 [..............................] - ETA: 3:34:38 - loss: 3.4147 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4675 - mrcnn_class_loss: 0.6475 - mrcnn_bbox_loss: 0.9350 - mrcnn_mask_loss: 1.3579
#    5/1037 [..............................] - ETA: 2:52:55 - loss: 3.1436 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.4496 - mrcnn_class_loss: 0.5325 - mrcnn_bbox_loss: 0.8667 - mrcnn_mask_loss: 1.2880
#    6/1037 [..............................] - ETA: 2:25:08 - loss: 2.9184 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.4273 - mrcnn_class_loss: 0.4551 - mrcnn_bbox_loss: 0.8183 - mrcnn_mask_loss: 1.2110
#    7/1037 [..............................] - ETA: 2:05:19 - loss: 2.7232 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.4025 - mrcnn_class_loss: 0.4008 - mrcnn_bbox_loss: 0.7813 - mrcnn_mask_loss: 1.1320
#    8/1037 [..............................] - ETA: 1:50:23 - loss: 2.5408 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.3770 - mrcnn_class_loss: 0.3605 - mrcnn_bbox_loss: 0.7379 - mrcnn_mask_loss: 1.0589
#    9/1037 [..............................] - ETA: 1:38:46 - loss: 2.6651 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.5868 - mrcnn_class_loss: 0.3206 - mrcnn_bbox_loss: 0.7428 - mrcnn_mask_loss: 1.0081
#   10/1037 [..............................] - ETA: 1:29:31 - loss: 2.7591 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.7376 - mrcnn_class_loss: 0.2889 - mrcnn_bbox_loss: 0.7580 - mrcnn_mask_loss: 0.9676
#   11/1037 [..............................] - ETA: 1:21:56 - loss: 2.7869 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.8315 - mrcnn_class_loss: 0.2628 - mrcnn_bbox_loss: 0.7496 - mrcnn_mask_loss: 0.9359
#   12/1037 [..............................] - ETA: 1:15:38 - loss: 2.7743 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.8766 - mrcnn_class_loss: 0.2410 - mrcnn_bbox_loss: 0.7345 - mrcnn_mask_loss: 0.9151
#   13/1037 [..............................] - ETA: 1:10:16 - loss: 2.7511 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.8914 - mrcnn_class_loss: 0.2227 - mrcnn_bbox_loss: 0.7345 - mrcnn_mask_loss: 0.8957
#   14/1037 [..............................] - ETA: 1:05:38 - loss: 2.7080 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.8831 - mrcnn_class_loss: 0.2070 - mrcnn_bbox_loss: 0.7307 - mrcnn_mask_loss: 0.8805
#   15/1037 [..............................] - ETA: 1:01:36 - loss: 2.6459 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.8601 - mrcnn_class_loss: 0.1936 - mrcnn_bbox_loss: 0.7156 - mrcnn_mask_loss: 0.8701
#   16/1037 [..............................] - ETA: 58:07 - loss: 2.5702 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.8286 - mrcnn_class_loss: 0.1851 - mrcnn_bbox_loss: 0.6936 - mrcnn_mask_loss: 0.8568
#   17/1037 [..............................] - ETA: 55:05 - loss: 2.5748 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.8565 - mrcnn_class_loss: 0.1775 - mrcnn_bbox_loss: 0.6940 - mrcnn_mask_loss: 0.8404
#   18/1037 [..............................] - ETA: 52:20 - loss: 2.5589 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.8682 - mrcnn_class_loss: 0.1703 - mrcnn_bbox_loss: 0.6879 - mrcnn_mask_loss: 0.8258
#   19/1037 [..............................] - ETA: 49:52 - loss: 2.5240 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.8575 - mrcnn_class_loss: 0.1649 - mrcnn_bbox_loss: 0.6831 - mrcnn_mask_loss: 0.8119
#   20/1037 [..............................] - ETA: 47:39 - loss: 2.4739 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.8344 - mrcnn_class_loss: 0.1591 - mrcnn_bbox_loss: 0.6758 - mrcnn_mask_loss: 0.7982
#   21/1037 [..............................] - ETA: 45:39 - loss: 2.4235 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.8061 - mrcnn_class_loss: 0.1537 - mrcnn_bbox_loss: 0.6722 - mrcnn_mask_loss: 0.7853
#   22/1037 [..............................] - ETA: 43:52 - loss: 2.3647 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.7785 - mrcnn_class_loss: 0.1489 - mrcnn_bbox_loss: 0.6587 - mrcnn_mask_loss: 0.7725
#   23/1037 [..............................] - ETA: 42:14 - loss: 2.3059 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.7525 - mrcnn_class_loss: 0.1436 - mrcnn_bbox_loss: 0.6441 - mrcnn_mask_loss: 0.7598
#   24/1037 [..............................] - ETA: 40:42 - loss: 2.2780 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.7298 - mrcnn_class_loss: 0.1419 - mrcnn_bbox_loss: 0.6521 - mrcnn_mask_loss: 0.7485
#   25/1037 [..............................] - ETA: 39:19 - loss: 2.2458 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.7084 - mrcnn_class_loss: 0.1404 - mrcnn_bbox_loss: 0.6534 - mrcnn_mask_loss: 0.7380
#   26/1037 [..............................] - ETA: 38:01 - loss: 2.1944 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.6852 - mrcnn_class_loss: 0.1369 - mrcnn_bbox_loss: 0.6408 - mrcnn_mask_loss: 0.7261
#   27/1037 [..............................] - ETA: 36:49 - loss: 2.1533 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.6658 - mrcnn_class_loss: 0.1350 - mrcnn_bbox_loss: 0.6311 - mrcnn_mask_loss: 0.7161
#   28/1037 [..............................] - ETA: 35:44 - loss: 2.1093 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.6471 - mrcnn_class_loss: 0.1324 - mrcnn_bbox_loss: 0.6190 - mrcnn_mask_loss: 0.7058
#   29/1037 [..............................] - ETA: 34:42 - loss: 2.0637 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.6286 - mrcnn_class_loss: 0.1306 - mrcnn_bbox_loss: 0.6047 - mrcnn_mask_loss: 0.6949
#   30/1037 [..............................] - ETA: 33:44 - loss: 2.0187 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.6106 - mrcnn_class_loss: 0.1279 - mrcnn_bbox_loss: 0.5925 - mrcnn_mask_loss: 0.6830
#   31/1037 [..............................] - ETA: 32:50 - loss: 1.9756 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.5930 - mrcnn_class_loss: 0.1262 - mrcnn_bbox_loss: 0.5812 - mrcnn_mask_loss: 0.6706
#   32/1037 [..............................] - ETA: 31:57 - loss: 1.9318 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5759 - mrcnn_class_loss: 0.1239 - mrcnn_bbox_loss: 0.5687 - mrcnn_mask_loss: 0.6588
#   33/1037 [..............................] - ETA: 31:10 - loss: 1.9407 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5836 - mrcnn_class_loss: 0.1223 - mrcnn_bbox_loss: 0.5710 - mrcnn_mask_loss: 0.6592
#   34/1037 [..............................] - ETA: 30:25 - loss: 1.9420 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.5905 - mrcnn_class_loss: 0.1193 - mrcnn_bbox_loss: 0.5672 - mrcnn_mask_loss: 0.6604
#   35/1037 [>.............................] - ETA: 29:42 - loss: 1.9367 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.5942 - mrcnn_class_loss: 0.1171 - mrcnn_bbox_loss: 0.5589 - mrcnn_mask_loss: 0.6620
#   36/1037 [>.............................] - ETA: 29:02 - loss: 1.9252 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5929 - mrcnn_class_loss: 0.1151 - mrcnn_bbox_loss: 0.5492 - mrcnn_mask_loss: 0.6635
#   37/1037 [>.............................] - ETA: 28:23 - loss: 1.9101 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5866 - mrcnn_class_loss: 0.1145 - mrcnn_bbox_loss: 0.5422 - mrcnn_mask_loss: 0.6622
#   38/1037 [>.............................] - ETA: 27:47 - loss: 1.8916 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5766 - mrcnn_class_loss: 0.1137 - mrcnn_bbox_loss: 0.5353 - mrcnn_mask_loss: 0.6615
#   39/1037 [>.............................] - ETA: 27:12 - loss: 1.8743 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.5652 - mrcnn_class_loss: 0.1141 - mrcnn_bbox_loss: 0.5302 - mrcnn_mask_loss: 0.6603
#   40/1037 [>.............................] - ETA: 26:39 - loss: 1.8679 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.5616 - mrcnn_class_loss: 0.1123 - mrcnn_bbox_loss: 0.5274 - mrcnn_mask_loss: 0.6623
#   41/1037 [>.............................] - ETA: 26:07 - loss: 1.8503 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.5517 - mrcnn_class_loss: 0.1118 - mrcnn_bbox_loss: 0.5229 - mrcnn_mask_loss: 0.6595
#   42/1037 [>.............................] - ETA: 25:37 - loss: 1.8394 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.5451 - mrcnn_class_loss: 0.1106 - mrcnn_bbox_loss: 0.5195 - mrcnn_mask_loss: 0.6599
#   43/1037 [>.............................] - ETA: 25:08 - loss: 1.8253 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.5372 - mrcnn_class_loss: 0.1093 - mrcnn_bbox_loss: 0.5160 - mrcnn_mask_loss: 0.6586
#   44/1037 [>.............................] - ETA: 24:41 - loss: 1.8094 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.5282 - mrcnn_class_loss: 0.1085 - mrcnn_bbox_loss: 0.5124 - mrcnn_mask_loss: 0.6561
#   45/1037 [>.............................] - ETA: 24:16 - loss: 1.7903 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.5188 - mrcnn_class_loss: 0.1081 - mrcnn_bbox_loss: 0.5069 - mrcnn_mask_loss: 0.6523
#   46/1037 [>.............................] - ETA: 23:51 - loss: 1.7690 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.5096 - mrcnn_class_loss: 0.1067 - mrcnn_bbox_loss: 0.5008 - mrcnn_mask_loss: 0.6478
#   47/1037 [>.............................] - ETA: 23:26 - loss: 1.7487 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.5009 - mrcnn_class_loss: 0.1065 - mrcnn_bbox_loss: 0.4942 - mrcnn_mask_loss: 0.6431
#   48/1037 [>.............................] - ETA: 23:03 - loss: 1.7455 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.4997 - mrcnn_class_loss: 0.1051 - mrcnn_bbox_loss: 0.4959 - mrcnn_mask_loss: 0.6408
#   49/1037 [>.............................] - ETA: 22:41 - loss: 1.7263 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.4916 - mrcnn_class_loss: 0.1040 - mrcnn_bbox_loss: 0.4904 - mrcnn_mask_loss: 0.6364
#   50/1037 [>.............................] - ETA: 22:21 - loss: 1.7204 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.4900 - mrcnn_class_loss: 0.1026 - mrcnn_bbox_loss: 0.4879 - mrcnn_mask_loss: 0.6362
#   51/1037 [>.............................] - ETA: 22:00 - loss: 1.7117 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.4879 - mrcnn_class_loss: 0.1014 - mrcnn_bbox_loss: 0.4825 - mrcnn_mask_loss: 0.6361
#   52/1037 [>.............................] - ETA: 21:40 - loss: 1.7004 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.4853 - mrcnn_class_loss: 0.1002 - mrcnn_bbox_loss: 0.4763 - mrcnn_mask_loss: 0.6349
#   53/1037 [>.............................] - ETA: 21:21 - loss: 1.6884 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.4820 - mrcnn_class_loss: 0.0990 - mrcnn_bbox_loss: 0.4708 - mrcnn_mask_loss: 0.6329
#   54/1037 [>.............................] - ETA: 21:03 - loss: 1.6744 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.4782 - mrcnn_class_loss: 0.0979 - mrcnn_bbox_loss: 0.4648 - mrcnn_mask_loss: 0.6299
#   55/1037 [>.............................] - ETA: 20:47 - loss: 1.6594 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.4739 - mrcnn_class_loss: 0.0967 - mrcnn_bbox_loss: 0.4593 - mrcnn_mask_loss: 0.6260
#   56/1037 [>.............................] - ETA: 20:31 - loss: 1.6433 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.4691 - mrcnn_class_loss: 0.0954 - mrcnn_bbox_loss: 0.4538 - mrcnn_mask_loss: 0.6216
#   57/1037 [>.............................] - ETA: 20:15 - loss: 1.7328 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.5558 - mrcnn_class_loss: 0.0940 - mrcnn_bbox_loss: 0.4613 - mrcnn_mask_loss: 0.6177
#   58/1037 [>.............................] - ETA: 20:00 - loss: 1.8108 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.6343 - mrcnn_class_loss: 0.0925 - mrcnn_bbox_loss: 0.4665 - mrcnn_mask_loss: 0.6132
#   59/1037 [>.............................] - ETA: 19:45 - loss: 1.8739 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.7012 - mrcnn_class_loss: 0.0910 - mrcnn_bbox_loss: 0.4688 - mrcnn_mask_loss: 0.6080
#   60/1037 [>.............................] - ETA: 19:31 - loss: 1.9193 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.7544 - mrcnn_class_loss: 0.0898 - mrcnn_bbox_loss: 0.4673 - mrcnn_mask_loss: 0.6027
#   61/1037 [>.............................] - ETA: 19:17 - loss: 1.9189 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.7562 - mrcnn_class_loss: 0.0885 - mrcnn_bbox_loss: 0.4695 - mrcnn_mask_loss: 0.5996
#   62/1037 [>.............................] - ETA: 19:03 - loss: 1.9325 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.7825 - mrcnn_class_loss: 0.0872 - mrcnn_bbox_loss: 0.4646 - mrcnn_mask_loss: 0.5929
#   63/1037 [>.............................] - ETA: 18:50 - loss: 1.9343 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.7958 - mrcnn_class_loss: 0.0859 - mrcnn_bbox_loss: 0.4608 - mrcnn_mask_loss: 0.5863
#   64/1037 [>.............................] - ETA: 18:37 - loss: 1.9277 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.7965 - mrcnn_class_loss: 0.0849 - mrcnn_bbox_loss: 0.4596 - mrcnn_mask_loss: 0.5810
#   65/1037 [>.............................] - ETA: 18:24 - loss: 1.9212 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.7944 - mrcnn_class_loss: 0.0840 - mrcnn_bbox_loss: 0.4586 - mrcnn_mask_loss: 0.5785
#   66/1037 [>.............................] - ETA: 18:11 - loss: 1.9126 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.7917 - mrcnn_class_loss: 0.0832 - mrcnn_bbox_loss: 0.4561 - mrcnn_mask_loss: 0.5760
#   67/1037 [>.............................] - ETA: 17:59 - loss: 1.9033 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.7895 - mrcnn_class_loss: 0.0825 - mrcnn_bbox_loss: 0.4536 - mrcnn_mask_loss: 0.5720
#   68/1037 [>.............................] - ETA: 17:48 - loss: 1.8937 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.7857 - mrcnn_class_loss: 0.0818 - mrcnn_bbox_loss: 0.4510 - mrcnn_mask_loss: 0.5697
#   69/1037 [>.............................] - ETA: 17:37 - loss: 1.8844 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.7816 - mrcnn_class_loss: 0.0811 - mrcnn_bbox_loss: 0.4489 - mrcnn_mask_loss: 0.5673
#   70/1037 [=>............................] - ETA: 17:26 - loss: 1.8803 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.7756 - mrcnn_class_loss: 0.0806 - mrcnn_bbox_loss: 0.4500 - mrcnn_mask_loss: 0.5686
#   71/1037 [=>............................] - ETA: 17:16 - loss: 1.8701 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.7714 - mrcnn_class_loss: 0.0798 - mrcnn_bbox_loss: 0.4474 - mrcnn_mask_loss: 0.5661
#   72/1037 [=>............................] - ETA: 17:05 - loss: 1.8588 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.7670 - mrcnn_class_loss: 0.0793 - mrcnn_bbox_loss: 0.4440 - mrcnn_mask_loss: 0.5633
#   73/1037 [=>............................] - ETA: 16:55 - loss: 1.8463 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.7621 - mrcnn_class_loss: 0.0786 - mrcnn_bbox_loss: 0.4401 - mrcnn_mask_loss: 0.5603
#   74/1037 [=>............................] - ETA: 16:45 - loss: 1.8403 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.7562 - mrcnn_class_loss: 0.0785 - mrcnn_bbox_loss: 0.4401 - mrcnn_mask_loss: 0.5603
#   75/1037 [=>............................] - ETA: 16:36 - loss: 1.8322 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.7498 - mrcnn_class_loss: 0.0783 - mrcnn_bbox_loss: 0.4392 - mrcnn_mask_loss: 0.5598
#   76/1037 [=>............................] - ETA: 16:27 - loss: 1.8219 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.7428 - mrcnn_class_loss: 0.0778 - mrcnn_bbox_loss: 0.4373 - mrcnn_mask_loss: 0.5589
#   77/1037 [=>............................] - ETA: 16:18 - loss: 1.8098 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.7353 - mrcnn_class_loss: 0.0770 - mrcnn_bbox_loss: 0.4346 - mrcnn_mask_loss: 0.5578
#   78/1037 [=>............................] - ETA: 16:09 - loss: 1.7974 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.7276 - mrcnn_class_loss: 0.0764 - mrcnn_bbox_loss: 0.4316 - mrcnn_mask_loss: 0.5568
#   79/1037 [=>............................] - ETA: 16:01 - loss: 1.7907 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.7208 - mrcnn_class_loss: 0.0763 - mrcnn_bbox_loss: 0.4324 - mrcnn_mask_loss: 0.5562
#   80/1037 [=>............................] - ETA: 15:53 - loss: 1.7789 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.7132 - mrcnn_class_loss: 0.0757 - mrcnn_bbox_loss: 0.4306 - mrcnn_mask_loss: 0.5545
#   81/1037 [=>............................] - ETA: 15:45 - loss: 1.7678 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.7058 - mrcnn_class_loss: 0.0752 - mrcnn_bbox_loss: 0.4294 - mrcnn_mask_loss: 0.5526
#   82/1037 [=>............................] - ETA: 15:36 - loss: 1.7593 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.7004 - mrcnn_class_loss: 0.0748 - mrcnn_bbox_loss: 0.4278 - mrcnn_mask_loss: 0.5514
#   83/1037 [=>............................] - ETA: 15:29 - loss: 1.7555 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.6986 - mrcnn_class_loss: 0.0741 - mrcnn_bbox_loss: 0.4286 - mrcnn_mask_loss: 0.5494
#   84/1037 [=>............................] - ETA: 15:21 - loss: 1.7461 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.6931 - mrcnn_class_loss: 0.0737 - mrcnn_bbox_loss: 0.4264 - mrcnn_mask_loss: 0.5481
#   85/1037 [=>............................] - ETA: 15:13 - loss: 1.7357 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.6872 - mrcnn_class_loss: 0.0732 - mrcnn_bbox_loss: 0.4239 - mrcnn_mask_loss: 0.5466
#   86/1037 [=>............................] - ETA: 15:06 - loss: 1.7242 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.6808 - mrcnn_class_loss: 0.0727 - mrcnn_bbox_loss: 0.4209 - mrcnn_mask_loss: 0.5451
#   87/1037 [=>............................] - ETA: 14:59 - loss: 1.7121 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.6738 - mrcnn_class_loss: 0.0723 - mrcnn_bbox_loss: 0.4175 - mrcnn_mask_loss: 0.5437
#   88/1037 [=>............................] - ETA: 14:52 - loss: 1.6996 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.6665 - mrcnn_class_loss: 0.0718 - mrcnn_bbox_loss: 0.4143 - mrcnn_mask_loss: 0.5423
#   89/1037 [=>............................] - ETA: 14:44 - loss: 1.6923 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6629 - mrcnn_class_loss: 0.0715 - mrcnn_bbox_loss: 0.4132 - mrcnn_mask_loss: 0.5400
#   90/1037 [=>............................] - ETA: 14:38 - loss: 1.6850 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6570 - mrcnn_class_loss: 0.0709 - mrcnn_bbox_loss: 0.4139 - mrcnn_mask_loss: 0.5386
#   91/1037 [=>............................] - ETA: 14:32 - loss: 1.6755 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6506 - mrcnn_class_loss: 0.0703 - mrcnn_bbox_loss: 0.4127 - mrcnn_mask_loss: 0.5373
#   92/1037 [=>............................] - ETA: 14:25 - loss: 1.6646 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6442 - mrcnn_class_loss: 0.0697 - mrcnn_bbox_loss: 0.4103 - mrcnn_mask_loss: 0.5357
#   93/1037 [=>............................] - ETA: 14:19 - loss: 1.6571 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6406 - mrcnn_class_loss: 0.0691 - mrcnn_bbox_loss: 0.4090 - mrcnn_mask_loss: 0.5338
#   94/1037 [=>............................] - ETA: 14:13 - loss: 1.6463 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6350 - mrcnn_class_loss: 0.0686 - mrcnn_bbox_loss: 0.4061 - mrcnn_mask_loss: 0.5321
#   95/1037 [=>............................] - ETA: 14:07 - loss: 1.6365 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.6294 - mrcnn_class_loss: 0.0683 - mrcnn_bbox_loss: 0.4038 - mrcnn_mask_loss: 0.5305
#   96/1037 [=>............................] - ETA: 14:00 - loss: 1.6262 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.6237 - mrcnn_class_loss: 0.0680 - mrcnn_bbox_loss: 0.4014 - mrcnn_mask_loss: 0.5286
#   97/1037 [=>............................] - ETA: 13:54 - loss: 1.6207 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.6226 - mrcnn_class_loss: 0.0677 - mrcnn_bbox_loss: 0.4002 - mrcnn_mask_loss: 0.5258
#   98/1037 [=>............................] - ETA: 13:49 - loss: 1.6135 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.6207 - mrcnn_class_loss: 0.0672 - mrcnn_bbox_loss: 0.3982 - mrcnn_mask_loss: 0.5229
#   99/1037 [=>............................] - ETA: 13:43 - loss: 1.6390 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.6411 - mrcnn_class_loss: 0.0674 - mrcnn_bbox_loss: 0.4032 - mrcnn_mask_loss: 0.5226
#  100/1037 [=>............................] - ETA: 13:38 - loss: 1.6296 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.6374 - mrcnn_class_loss: 0.0669 - mrcnn_bbox_loss: 0.4008 - mrcnn_mask_loss: 0.5198
#  101/1037 [=>............................] - ETA: 13:33 - loss: 1.6201 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6331 - mrcnn_class_loss: 0.0666 - mrcnn_bbox_loss: 0.3987 - mrcnn_mask_loss: 0.5171
#  102/1037 [=>............................] - ETA: 13:28 - loss: 1.6146 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6289 - mrcnn_class_loss: 0.0661 - mrcnn_bbox_loss: 0.4003 - mrcnn_mask_loss: 0.5147
#  103/1037 [=>............................] - ETA: 13:23 - loss: 1.6039 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.6238 - mrcnn_class_loss: 0.0659 - mrcnn_bbox_loss: 0.3976 - mrcnn_mask_loss: 0.5121
#  104/1037 [==>...........................] - ETA: 13:18 - loss: 1.5925 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.6184 - mrcnn_class_loss: 0.0656 - mrcnn_bbox_loss: 0.3947 - mrcnn_mask_loss: 0.5093
#  105/1037 [==>...........................] - ETA: 13:13 - loss: 1.6021 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.6296 - mrcnn_class_loss: 0.0652 - mrcnn_bbox_loss: 0.3954 - mrcnn_mask_loss: 0.5071
#  106/1037 [==>...........................] - ETA: 13:08 - loss: 1.6073 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.6378 - mrcnn_class_loss: 0.0649 - mrcnn_bbox_loss: 0.3948 - mrcnn_mask_loss: 0.5048
#  107/1037 [==>...........................] - ETA: 13:03 - loss: 1.6067 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.6415 - mrcnn_class_loss: 0.0645 - mrcnn_bbox_loss: 0.3930 - mrcnn_mask_loss: 0.5025
#  108/1037 [==>...........................] - ETA: 12:58 - loss: 1.6002 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.6366 - mrcnn_class_loss: 0.0644 - mrcnn_bbox_loss: 0.3919 - mrcnn_mask_loss: 0.5021
#  109/1037 [==>...........................] - ETA: 12:54 - loss: 1.5891 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.6312 - mrcnn_class_loss: 0.0640 - mrcnn_bbox_loss: 0.3896 - mrcnn_mask_loss: 0.4992
#  110/1037 [==>...........................] - ETA: 12:49 - loss: 1.5870 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.6275 - mrcnn_class_loss: 0.0650 - mrcnn_bbox_loss: 0.3903 - mrcnn_mask_loss: 0.4988
#  111/1037 [==>...........................] - ETA: 12:45 - loss: 1.5854 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.6241 - mrcnn_class_loss: 0.0661 - mrcnn_bbox_loss: 0.3912 - mrcnn_mask_loss: 0.4986
#  112/1037 [==>...........................] - ETA: 12:40 - loss: 1.5828 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.6204 - mrcnn_class_loss: 0.0670 - mrcnn_bbox_loss: 0.3917 - mrcnn_mask_loss: 0.4982
#  113/1037 [==>...........................] - ETA: 12:36 - loss: 1.5755 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.6156 - mrcnn_class_loss: 0.0668 - mrcnn_bbox_loss: 0.3901 - mrcnn_mask_loss: 0.4975
#  114/1037 [==>...........................] - ETA: 12:32 - loss: 1.5675 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.6109 - mrcnn_class_loss: 0.0665 - mrcnn_bbox_loss: 0.3881 - mrcnn_mask_loss: 0.4965
#  115/1037 [==>...........................] - ETA: 12:28 - loss: 1.5591 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.6061 - mrcnn_class_loss: 0.0661 - mrcnn_bbox_loss: 0.3859 - mrcnn_mask_loss: 0.4955
#  116/1037 [==>...........................] - ETA: 12:24 - loss: 1.5549 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.6051 - mrcnn_class_loss: 0.0663 - mrcnn_bbox_loss: 0.3847 - mrcnn_mask_loss: 0.4934
#  117/1037 [==>...........................] - ETA: 12:20 - loss: 1.5515 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.6009 - mrcnn_class_loss: 0.0661 - mrcnn_bbox_loss: 0.3864 - mrcnn_mask_loss: 0.4925
#  118/1037 [==>...........................] - ETA: 12:16 - loss: 1.5427 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5961 - mrcnn_class_loss: 0.0657 - mrcnn_bbox_loss: 0.3843 - mrcnn_mask_loss: 0.4912
#  119/1037 [==>...........................] - ETA: 12:12 - loss: 1.5336 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5913 - mrcnn_class_loss: 0.0652 - mrcnn_bbox_loss: 0.3818 - mrcnn_mask_loss: 0.4899
#  120/1037 [==>...........................] - ETA: 12:08 - loss: 1.5244 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5866 - mrcnn_class_loss: 0.0648 - mrcnn_bbox_loss: 0.3792 - mrcnn_mask_loss: 0.4884
#  121/1037 [==>...........................] - ETA: 12:04 - loss: 1.5187 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5850 - mrcnn_class_loss: 0.0646 - mrcnn_bbox_loss: 0.3776 - mrcnn_mask_loss: 0.4860
#  122/1037 [==>...........................] - ETA: 12:01 - loss: 1.5124 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5831 - mrcnn_class_loss: 0.0644 - mrcnn_bbox_loss: 0.3758 - mrcnn_mask_loss: 0.4836
#  123/1037 [==>...........................] - ETA: 11:57 - loss: 1.5053 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5805 - mrcnn_class_loss: 0.0642 - mrcnn_bbox_loss: 0.3739 - mrcnn_mask_loss: 0.4813
#  124/1037 [==>...........................] - ETA: 11:54 - loss: 1.5039 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5796 - mrcnn_class_loss: 0.0640 - mrcnn_bbox_loss: 0.3746 - mrcnn_mask_loss: 0.4802
#  125/1037 [==>...........................] - ETA: 11:50 - loss: 1.4954 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5760 - mrcnn_class_loss: 0.0637 - mrcnn_bbox_loss: 0.3723 - mrcnn_mask_loss: 0.4778
#  126/1037 [==>...........................] - ETA: 11:47 - loss: 1.4884 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5725 - mrcnn_class_loss: 0.0633 - mrcnn_bbox_loss: 0.3706 - mrcnn_mask_loss: 0.4765
#  127/1037 [==>...........................] - ETA: 11:44 - loss: 1.4795 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5684 - mrcnn_class_loss: 0.0630 - mrcnn_bbox_loss: 0.3684 - mrcnn_mask_loss: 0.4741
#  128/1037 [==>...........................] - ETA: 11:40 - loss: 1.4705 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5642 - mrcnn_class_loss: 0.0627 - mrcnn_bbox_loss: 0.3662 - mrcnn_mask_loss: 0.4719
#  129/1037 [==>...........................] - ETA: 11:38 - loss: 1.4674 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5633 - mrcnn_class_loss: 0.0624 - mrcnn_bbox_loss: 0.3655 - mrcnn_mask_loss: 0.4708
#  130/1037 [==>...........................] - ETA: 11:35 - loss: 1.4639 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5621 - mrcnn_class_loss: 0.0621 - mrcnn_bbox_loss: 0.3645 - mrcnn_mask_loss: 0.4696
#  131/1037 [==>...........................] - ETA: 11:32 - loss: 1.4592 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5605 - mrcnn_class_loss: 0.0619 - mrcnn_bbox_loss: 0.3629 - mrcnn_mask_loss: 0.4684
#  132/1037 [==>...........................] - ETA: 11:29 - loss: 1.4551 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.5588 - mrcnn_class_loss: 0.0618 - mrcnn_bbox_loss: 0.3621 - mrcnn_mask_loss: 0.4669
#  133/1037 [==>...........................] - ETA: 11:26 - loss: 1.4490 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5561 - mrcnn_class_loss: 0.0614 - mrcnn_bbox_loss: 0.3606 - mrcnn_mask_loss: 0.4655
#  134/1037 [==>...........................] - ETA: 11:23 - loss: 1.4425 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5532 - mrcnn_class_loss: 0.0612 - mrcnn_bbox_loss: 0.3591 - mrcnn_mask_loss: 0.4635
#  135/1037 [==>...........................] - ETA: 11:20 - loss: 1.4361 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5500 - mrcnn_class_loss: 0.0609 - mrcnn_bbox_loss: 0.3579 - mrcnn_mask_loss: 0.4620
#  136/1037 [==>...........................] - ETA: 11:17 - loss: 1.4294 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5466 - mrcnn_class_loss: 0.0606 - mrcnn_bbox_loss: 0.3563 - mrcnn_mask_loss: 0.4604
#  137/1037 [==>...........................] - ETA: 11:13 - loss: 1.4240 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5441 - mrcnn_class_loss: 0.0604 - mrcnn_bbox_loss: 0.3552 - mrcnn_mask_loss: 0.4589
#  138/1037 [==>...........................] - ETA: 11:10 - loss: 1.4182 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5416 - mrcnn_class_loss: 0.0601 - mrcnn_bbox_loss: 0.3537 - mrcnn_mask_loss: 0.4573
#  139/1037 [===>..........................] - ETA: 11:07 - loss: 1.4120 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5390 - mrcnn_class_loss: 0.0599 - mrcnn_bbox_loss: 0.3519 - mrcnn_mask_loss: 0.4557
#  140/1037 [===>..........................] - ETA: 11:04 - loss: 1.4183 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5427 - mrcnn_class_loss: 0.0597 - mrcnn_bbox_loss: 0.3514 - mrcnn_mask_loss: 0.4591
#  141/1037 [===>..........................] - ETA: 11:01 - loss: 1.4120 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5399 - mrcnn_class_loss: 0.0594 - mrcnn_bbox_loss: 0.3499 - mrcnn_mask_loss: 0.4574
#  142/1037 [===>..........................] - ETA: 10:59 - loss: 1.4076 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5366 - mrcnn_class_loss: 0.0592 - mrcnn_bbox_loss: 0.3507 - mrcnn_mask_loss: 0.4557
#  143/1037 [===>..........................] - ETA: 10:56 - loss: 1.4012 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5337 - mrcnn_class_loss: 0.0588 - mrcnn_bbox_loss: 0.3493 - mrcnn_mask_loss: 0.4539
#  144/1037 [===>..........................] - ETA: 10:53 - loss: 1.3944 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5308 - mrcnn_class_loss: 0.0585 - mrcnn_bbox_loss: 0.3475 - mrcnn_mask_loss: 0.4521
#  145/1037 [===>..........................] - ETA: 10:50 - loss: 1.3997 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5349 - mrcnn_class_loss: 0.0583 - mrcnn_bbox_loss: 0.3471 - mrcnn_mask_loss: 0.4540
#  146/1037 [===>..........................] - ETA: 10:47 - loss: 1.4038 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5388 - mrcnn_class_loss: 0.0580 - mrcnn_bbox_loss: 0.3464 - mrcnn_mask_loss: 0.4552
#  147/1037 [===>..........................] - ETA: 10:44 - loss: 1.4068 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5422 - mrcnn_class_loss: 0.0577 - mrcnn_bbox_loss: 0.3454 - mrcnn_mask_loss: 0.4560
#  148/1037 [===>..........................] - ETA: 10:41 - loss: 1.4095 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5424 - mrcnn_class_loss: 0.0576 - mrcnn_bbox_loss: 0.3486 - mrcnn_mask_loss: 0.4556
#  149/1037 [===>..........................] - ETA: 10:39 - loss: 1.4094 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5444 - mrcnn_class_loss: 0.0573 - mrcnn_bbox_loss: 0.3470 - mrcnn_mask_loss: 0.4553
#  150/1037 [===>..........................] - ETA: 10:36 - loss: 1.4046 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5413 - mrcnn_class_loss: 0.0571 - mrcnn_bbox_loss: 0.3468 - mrcnn_mask_loss: 0.4540
#  151/1037 [===>..........................] - ETA: 10:33 - loss: 1.4031 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5418 - mrcnn_class_loss: 0.0568 - mrcnn_bbox_loss: 0.3460 - mrcnn_mask_loss: 0.4532
#  152/1037 [===>..........................] - ETA: 10:31 - loss: 1.4008 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5414 - mrcnn_class_loss: 0.0565 - mrcnn_bbox_loss: 0.3451 - mrcnn_mask_loss: 0.4523
#  153/1037 [===>..........................] - ETA: 10:28 - loss: 1.3984 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5403 - mrcnn_class_loss: 0.0562 - mrcnn_bbox_loss: 0.3453 - mrcnn_mask_loss: 0.4512
#  154/1037 [===>..........................] - ETA: 10:25 - loss: 1.3950 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5388 - mrcnn_class_loss: 0.0560 - mrcnn_bbox_loss: 0.3449 - mrcnn_mask_loss: 0.4499
#  155/1037 [===>..........................] - ETA: 10:22 - loss: 1.3905 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5367 - mrcnn_class_loss: 0.0558 - mrcnn_bbox_loss: 0.3440 - mrcnn_mask_loss: 0.4486
#  156/1037 [===>..........................] - ETA: 10:20 - loss: 1.3849 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5341 - mrcnn_class_loss: 0.0555 - mrcnn_bbox_loss: 0.3427 - mrcnn_mask_loss: 0.4472
#  157/1037 [===>..........................] - ETA: 10:18 - loss: 1.3816 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5333 - mrcnn_class_loss: 0.0554 - mrcnn_bbox_loss: 0.3413 - mrcnn_mask_loss: 0.4463
#  158/1037 [===>..........................] - ETA: 10:15 - loss: 1.3779 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5315 - mrcnn_class_loss: 0.0551 - mrcnn_bbox_loss: 0.3408 - mrcnn_mask_loss: 0.4450
#  159/1037 [===>..........................] - ETA: 10:13 - loss: 1.3718 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5285 - mrcnn_class_loss: 0.0548 - mrcnn_bbox_loss: 0.3396 - mrcnn_mask_loss: 0.4435
#  160/1037 [===>..........................] - ETA: 10:10 - loss: 1.3658 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.5255 - mrcnn_class_loss: 0.0546 - mrcnn_bbox_loss: 0.3382 - mrcnn_mask_loss: 0.4420
#  161/1037 [===>..........................] - ETA: 10:07 - loss: 1.3621 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.5240 - mrcnn_class_loss: 0.0546 - mrcnn_bbox_loss: 0.3374 - mrcnn_mask_loss: 0.4408
#  162/1037 [===>..........................] - ETA: 10:05 - loss: 1.3581 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.5222 - mrcnn_class_loss: 0.0544 - mrcnn_bbox_loss: 0.3366 - mrcnn_mask_loss: 0.4396
#  163/1037 [===>..........................] - ETA: 10:03 - loss: 1.3522 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.5193 - mrcnn_class_loss: 0.0541 - mrcnn_bbox_loss: 0.3354 - mrcnn_mask_loss: 0.4380
#  164/1037 [===>..........................] - ETA: 10:00 - loss: 1.3473 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.5172 - mrcnn_class_loss: 0.0540 - mrcnn_bbox_loss: 0.3340 - mrcnn_mask_loss: 0.4368
#  165/1037 [===>..........................] - ETA: 9:58 - loss: 1.3483 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.5160 - mrcnn_class_loss: 0.0541 - mrcnn_bbox_loss: 0.3362 - mrcnn_mask_loss: 0.4368
#  166/1037 [===>..........................] - ETA: 9:55 - loss: 1.3428 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5136 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.3347 - mrcnn_mask_loss: 0.4354
#  167/1037 [===>..........................] - ETA: 9:53 - loss: 1.3422 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5121 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.3356 - mrcnn_mask_loss: 0.4353
#  168/1037 [===>..........................] - ETA: 9:51 - loss: 1.3365 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5096 - mrcnn_class_loss: 0.0537 - mrcnn_bbox_loss: 0.3341 - mrcnn_mask_loss: 0.4338
#  169/1037 [===>..........................] - ETA: 9:49 - loss: 1.3341 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5078 - mrcnn_class_loss: 0.0539 - mrcnn_bbox_loss: 0.3340 - mrcnn_mask_loss: 0.4333
#  170/1037 [===>..........................] - ETA: 9:47 - loss: 1.3281 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5053 - mrcnn_class_loss: 0.0537 - mrcnn_bbox_loss: 0.3323 - mrcnn_mask_loss: 0.4317
#  171/1037 [===>..........................] - ETA: 9:45 - loss: 1.3248 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5032 - mrcnn_class_loss: 0.0537 - mrcnn_bbox_loss: 0.3317 - mrcnn_mask_loss: 0.4311
#  172/1037 [===>..........................] - ETA: 9:43 - loss: 1.3189 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.5007 - mrcnn_class_loss: 0.0535 - mrcnn_bbox_loss: 0.3301 - mrcnn_mask_loss: 0.4295
#  173/1037 [====>.........................] - ETA: 9:41 - loss: 1.3149 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.4984 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.3291 - mrcnn_mask_loss: 0.4288
#  174/1037 [====>.........................] - ETA: 9:39 - loss: 1.3107 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.4962 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.3280 - mrcnn_mask_loss: 0.4282
#  175/1037 [====>.........................] - ETA: 9:37 - loss: 1.3141 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.4974 - mrcnn_class_loss: 0.0534 - mrcnn_bbox_loss: 0.3294 - mrcnn_mask_loss: 0.4287
#  176/1037 [====>.........................] - ETA: 9:35 - loss: 1.3169 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.4985 - mrcnn_class_loss: 0.0534 - mrcnn_bbox_loss: 0.3308 - mrcnn_mask_loss: 0.4291
#  177/1037 [====>.........................] - ETA: 9:34 - loss: 1.3125 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.4961 - mrcnn_class_loss: 0.0533 - mrcnn_bbox_loss: 0.3297 - mrcnn_mask_loss: 0.4284
#  178/1037 [====>.........................] - ETA: 9:32 - loss: 1.3079 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4938 - mrcnn_class_loss: 0.0531 - mrcnn_bbox_loss: 0.3283 - mrcnn_mask_loss: 0.4277
#  179/1037 [====>.........................] - ETA: 9:30 - loss: 1.3076 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4937 - mrcnn_class_loss: 0.0531 - mrcnn_bbox_loss: 0.3280 - mrcnn_mask_loss: 0.4277
#  180/1037 [====>.........................] - ETA: 9:29 - loss: 1.3066 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4932 - mrcnn_class_loss: 0.0531 - mrcnn_bbox_loss: 0.3277 - mrcnn_mask_loss: 0.4277
#  181/1037 [====>.........................] - ETA: 9:28 - loss: 1.3096 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4933 - mrcnn_class_loss: 0.0530 - mrcnn_bbox_loss: 0.3310 - mrcnn_mask_loss: 0.4274
#  182/1037 [====>.........................] - ETA: 9:26 - loss: 1.3125 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.4938 - mrcnn_class_loss: 0.0528 - mrcnn_bbox_loss: 0.3339 - mrcnn_mask_loss: 0.4271
#  183/1037 [====>.........................] - ETA: 9:25 - loss: 1.3098 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.4922 - mrcnn_class_loss: 0.0528 - mrcnn_bbox_loss: 0.3331 - mrcnn_mask_loss: 0.4269
#  184/1037 [====>.........................] - ETA: 9:23 - loss: 1.3064 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.4903 - mrcnn_class_loss: 0.0528 - mrcnn_bbox_loss: 0.3319 - mrcnn_mask_loss: 0.4265
#  185/1037 [====>.........................] - ETA: 9:22 - loss: 1.3073 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.4913 - mrcnn_class_loss: 0.0527 - mrcnn_bbox_loss: 0.3324 - mrcnn_mask_loss: 0.4261
#  186/1037 [====>.........................] - ETA: 9:20 - loss: 1.3072 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.4923 - mrcnn_class_loss: 0.0525 - mrcnn_bbox_loss: 0.3321 - mrcnn_mask_loss: 0.4255
#  187/1037 [====>.........................] - ETA: 9:18 - loss: 1.3043 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.4899 - mrcnn_class_loss: 0.0523 - mrcnn_bbox_loss: 0.3324 - mrcnn_mask_loss: 0.4249
#  188/1037 [====>.........................] - ETA: 9:17 - loss: 1.3177 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4993 - mrcnn_class_loss: 0.0521 - mrcnn_bbox_loss: 0.3365 - mrcnn_mask_loss: 0.4248
#  189/1037 [====>.........................] - ETA: 9:15 - loss: 1.3154 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.4968 - mrcnn_class_loss: 0.0520 - mrcnn_bbox_loss: 0.3373 - mrcnn_mask_loss: 0.4243
# ...
#  695/1037 [===================>..........] - ETA: 1:58 - loss: 0.6111 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2048 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2240
#  696/1037 [===================>..........] - ETA: 1:57 - loss: 0.6109 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2047 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2240
#  697/1037 [===================>..........] - ETA: 1:57 - loss: 0.6118 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2047 - mrcnn_class_loss: 0.0417 - mrcnn_bbox_loss: 0.1384 - mrcnn_mask_loss: 0.2242
#  698/1037 [===================>..........] - ETA: 1:57 - loss: 0.6113 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2045 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2241
#  699/1037 [===================>..........] - ETA: 1:56 - loss: 0.6108 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2043 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2239
#  700/1037 [===================>..........] - ETA: 1:56 - loss: 0.6105 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2042 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2238
#  701/1037 [===================>..........] - ETA: 1:56 - loss: 0.6101 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2039 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2238
#  702/1037 [===================>..........] - ETA: 1:55 - loss: 0.6105 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2038 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2239
#  703/1037 [===================>..........] - ETA: 1:55 - loss: 0.6101 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2036 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2238
#  704/1037 [===================>..........] - ETA: 1:55 - loss: 0.6097 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2034 - mrcnn_class_loss: 0.0416 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2238
#  705/1037 [===================>..........] - ETA: 1:54 - loss: 0.6160 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2094 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2240
#  706/1037 [===================>..........] - ETA: 1:54 - loss: 0.6155 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2092 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2238
#  707/1037 [===================>..........] - ETA: 1:53 - loss: 0.6150 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2090 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2237
#  708/1037 [===================>..........] - ETA: 1:53 - loss: 0.6146 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2087 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2237
#  709/1037 [===================>..........] - ETA: 1:53 - loss: 0.6141 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2085 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2236
#  710/1037 [===================>..........] - ETA: 1:52 - loss: 0.6189 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2131 - mrcnn_class_loss: 0.0414 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2237
#  711/1037 [===================>..........] - ETA: 1:52 - loss: 0.6184 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2128 - mrcnn_class_loss: 0.0414 - mrcnn_bbox_loss: 0.1377 - mrcnn_mask_loss: 0.2237
#  712/1037 [===================>..........] - ETA: 1:52 - loss: 0.6181 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2127 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1376 - mrcnn_mask_loss: 0.2237
#  713/1037 [===================>..........] - ETA: 1:51 - loss: 0.6204 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2148 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2236
#  714/1037 [===================>..........] - ETA: 1:51 - loss: 0.6198 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2146 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1376 - mrcnn_mask_loss: 0.2235
#  715/1037 [===================>..........] - ETA: 1:51 - loss: 0.6193 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2143 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2234
#  716/1037 [===================>..........] - ETA: 1:50 - loss: 0.6188 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2141 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2234
#  717/1037 [===================>..........] - ETA: 1:50 - loss: 0.6188 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2139 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2235
#  718/1037 [===================>..........] - ETA: 1:50 - loss: 0.6195 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2145 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1376 - mrcnn_mask_loss: 0.2234
#  719/1037 [===================>..........] - ETA: 1:49 - loss: 0.6190 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2142 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2234
#  720/1037 [===================>..........] - ETA: 1:49 - loss: 0.6209 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2153 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2236
#  721/1037 [===================>..........] - ETA: 1:49 - loss: 0.6223 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2166 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2238
#  722/1037 [===================>..........] - ETA: 1:48 - loss: 0.6218 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2163 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2237
#  723/1037 [===================>..........] - ETA: 1:48 - loss: 0.6213 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2160 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1377 - mrcnn_mask_loss: 0.2236
#  724/1037 [===================>..........] - ETA: 1:48 - loss: 0.6226 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2167 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2240
#  725/1037 [===================>..........] - ETA: 1:47 - loss: 0.6232 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2171 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2241
#  726/1037 [====================>.........] - ETA: 1:47 - loss: 0.6241 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2175 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2245
#  727/1037 [====================>.........] - ETA: 1:47 - loss: 0.6236 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2173 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2244
#  728/1037 [====================>.........] - ETA: 1:46 - loss: 0.6237 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2171 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2244
#  729/1037 [====================>.........] - ETA: 1:46 - loss: 0.6241 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2172 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2247
#  730/1037 [====================>.........] - ETA: 1:46 - loss: 0.6242 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2171 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2248
#  731/1037 [====================>.........] - ETA: 1:45 - loss: 0.6244 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2170 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2250
#  732/1037 [====================>.........] - ETA: 1:45 - loss: 0.6244 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2169 - mrcnn_class_loss: 0.0414 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2251
#  733/1037 [====================>.........] - ETA: 1:45 - loss: 0.6244 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2168 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2252
#  734/1037 [====================>.........] - ETA: 1:44 - loss: 0.6239 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2165 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2250
#  735/1037 [====================>.........] - ETA: 1:44 - loss: 0.6238 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2164 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2251
#  736/1037 [====================>.........] - ETA: 1:44 - loss: 0.6245 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2170 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2251
#  737/1037 [====================>.........] - ETA: 1:43 - loss: 0.6243 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2169 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2251
#  738/1037 [====================>.........] - ETA: 1:43 - loss: 0.6253 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2176 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2253
#  739/1037 [====================>.........] - ETA: 1:43 - loss: 0.6251 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2174 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2253
#  740/1037 [====================>.........] - ETA: 1:42 - loss: 0.6254 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2176 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2254
#  741/1037 [====================>.........] - ETA: 1:42 - loss: 0.6261 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2181 - mrcnn_class_loss: 0.0414 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2255
#  742/1037 [====================>.........] - ETA: 1:42 - loss: 0.6256 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2179 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2253
#  743/1037 [====================>.........] - ETA: 1:41 - loss: 0.6255 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2179 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2253
#  744/1037 [====================>.........] - ETA: 1:41 - loss: 0.6261 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2185 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1382 - mrcnn_mask_loss: 0.2253
#  745/1037 [====================>.........] - ETA: 1:41 - loss: 0.6259 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2184 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1381 - mrcnn_mask_loss: 0.2253
#  746/1037 [====================>.........] - ETA: 1:40 - loss: 0.6258 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2184 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2253
#  747/1037 [====================>.........] - ETA: 1:40 - loss: 0.6259 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2186 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2252
#  748/1037 [====================>.........] - ETA: 1:40 - loss: 0.6260 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2186 - mrcnn_class_loss: 0.0413 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2252
#  749/1037 [====================>.........] - ETA: 1:39 - loss: 0.6256 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2183 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1380 - mrcnn_mask_loss: 0.2251
#  750/1037 [====================>.........] - ETA: 1:39 - loss: 0.6253 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2183 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2251
#  751/1037 [====================>.........] - ETA: 1:39 - loss: 0.6252 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2182 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2250
#  752/1037 [====================>.........] - ETA: 1:38 - loss: 0.6253 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2183 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1379 - mrcnn_mask_loss: 0.2251
#  753/1037 [====================>.........] - ETA: 1:38 - loss: 0.6250 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2181 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.1378 - mrcnn_mask_loss: 0.2250
#  754/1037 [====================>.........] - ETA: 1:38 - loss: 0.6245 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2179 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1377 - mrcnn_mask_loss: 0.2249
#  755/1037 [====================>.........] - ETA: 1:37 - loss: 0.6245 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2179 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1377 - mrcnn_mask_loss: 0.2250
#  756/1037 [====================>.........] - ETA: 1:37 - loss: 0.6241 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2177 - mrcnn_class_loss: 0.0411 - mrcnn_bbox_loss: 0.1376 - mrcnn_mask_loss: 0.2249
#  757/1037 [====================>.........] - ETA: 1:37 - loss: 0.6239 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2175 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2250
#  758/1037 [====================>.........] - ETA: 1:36 - loss: 0.6240 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2174 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2251
#  759/1037 [====================>.........] - ETA: 1:36 - loss: 0.6240 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2173 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1376 - mrcnn_mask_loss: 0.2252
#  760/1037 [====================>.........] - ETA: 1:36 - loss: 0.6238 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2172 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2252
#  761/1037 [=====================>........] - ETA: 1:35 - loss: 0.6238 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2171 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.2253
#  762/1037 [=====================>........] - ETA: 1:35 - loss: 0.6235 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2170 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2254
#  763/1037 [=====================>........] - ETA: 1:35 - loss: 0.6234 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2168 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2254
#  764/1037 [=====================>........] - ETA: 1:34 - loss: 0.6235 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2166 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2256
#  765/1037 [=====================>........] - ETA: 1:34 - loss: 0.6233 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2164 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2256
#  766/1037 [=====================>........] - ETA: 1:34 - loss: 0.6233 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2165 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1374 - mrcnn_mask_loss: 0.2255
#  767/1037 [=====================>........] - ETA: 1:33 - loss: 0.6238 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2171 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1373 - mrcnn_mask_loss: 0.2255
#  768/1037 [=====================>........] - ETA: 1:33 - loss: 0.6234 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2168 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1372 - mrcnn_mask_loss: 0.2255
#  769/1037 [=====================>........] - ETA: 1:33 - loss: 0.6233 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2168 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1372 - mrcnn_mask_loss: 0.2254
#  770/1037 [=====================>........] - ETA: 1:32 - loss: 0.6229 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2165 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1371 - mrcnn_mask_loss: 0.2254
#  771/1037 [=====================>........] - ETA: 1:32 - loss: 0.6233 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2169 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1371 - mrcnn_mask_loss: 0.2254
#  772/1037 [=====================>........] - ETA: 1:31 - loss: 0.6231 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.2168 - mrcnn_class_loss: 0.0410 - mrcnn_bbox_loss: 0.1370 - mrcnn_mask_loss: 0.2254
#
# 2021-05-29 20:43:35 Uploading - Uploading generated training model
# 2021-05-29 20:43:35 Stopped - Training job stopped
# ProfilerReport-1622319294: IssuesFound
# Job ended with status 'Stopped' rather than 'Completed'. This could mean the job timed out or stopped early for some other reason: Consider checking whether it completed as you expect.
# Training seconds: 1387
# Billable seconds: 416
# Managed Spot Training savings: 70.0%
